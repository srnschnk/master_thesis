# %%
# pip install transformers

# %%
import os
import sys
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from collections import defaultdict
from itertools import product

from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import (accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, 
                             average_precision_score, precision_recall_curve, fbeta_score, confusion_matrix)

from imblearn.over_sampling import RandomOverSampler

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from torch.optim.lr_scheduler import ReduceLROnPlateau

from transformers import AutoModel, AutoTokenizer

from captum.attr import IntegratedGradients

# %%
# Load Custom Functions
sys.path.append('./model')
from custom_functions import load_raw_data, extract_icd_codes, extract_dynamic_data_dict, extract_demographic_features, summarize_dynamic_features

# %%
# Set Seed for all packages
def set_seed(seed=42):
    """Set seeds to make the experiment more reproducible."""
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)  # if you are using multi-GPU
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed(42)

# %% [markdown]
# # Load Data

# %%
# Define the percentage to load
percentage = '25%'  # Change this to '5%', '10%', etc., as needed

# Base directory for the data subsets
base_dir = f'./data/subsets/{percentage}_subsets/'

# Load Labels
labels = pd.read_csv(f'{base_dir}labels.csv')
stay_ids = labels['stay_id'].unique()

# Load static features
icd_features = pd.read_pickle(f'{base_dir}icd_code_features.pkl')

# Load summarized dynamic features
sum_dynamic_features = pd.read_pickle(f'{base_dir}sum_dynamic_features.pkl')

# Load demographic features
demographic_features = pd.read_pickle(f'{base_dir}demographic_features.pkl')

# Print information to confirm the files are loaded
print(f"Files for {percentage} subset loaded successfully.")
print(f"Number of stays: {len(stay_ids)}")
print(f"ICD Features shape: {icd_features.shape}")
print(f"Summarized Dynamic Features shape: {sum_dynamic_features.shape}")
print(f"Demographic Features shape: {demographic_features.shape}")
# Out:
# Files for 25% subset loaded successfully.
# Number of stays: 11895
# ICD Features shape: (11895, 1458)
# Summarized Dynamic Features shape: (11895, 16)
# Demographic Features shape: (11895, 4)

# %%
# Merge the DataFrames along the columns (axis=1)
all_static_features = pd.concat([icd_features, demographic_features], axis=1)

# %% [markdown]
# # Train Test Split

# %%
# Split data into training and temp sets (temp will be split into validation and test)
train_stays, temp_stays = train_test_split(labels, test_size=0.3, random_state=42, stratify=labels['label'])

# Now split temp into test and validation sets equally
test_stays, val_stays = train_test_split(temp_stays, test_size=0.5, random_state=42, stratify=temp_stays['label'])

# %% [markdown]
# # Scaling & Encoding of Static Features

# %%
# Create Slices of icd_code features for each set
icd_features_train = icd_features.loc[train_stays['stay_id']]
icd_features_val = icd_features.loc[val_stays['stay_id']]
icd_features_test = icd_features.loc[test_stays['stay_id']]

# %%
# Create Slices of all_static features for each set
static_features_train = all_static_features.loc[train_stays['stay_id']]
static_features_val = all_static_features.loc[val_stays['stay_id']]
static_features_test = all_static_features.loc[test_stays['stay_id']]

# %% [markdown]
# Continous Features

# %%
# Selecting Continious Columns for the Different Sets
continous_static_columns_train = static_features_train[["Age"]]
continous_static_columns_val = static_features_val[["Age"]]
continous_static_columns_test = static_features_test[["Age"]]

# %%
# Train Standard Scaler on the Train Set and apply it to Train, Validation and Test Set 
# Initialize the scaler
scaler = StandardScaler()

# Fit the scaler on the training data
scaler.fit(continous_static_columns_train)

# Scale Training Set in a way that yields a Data Frame again
continous_static_columns_train = pd.DataFrame(
    scaler.transform(continous_static_columns_train),
    index=continous_static_columns_train.index,
    columns=continous_static_columns_train.columns
)

# Scale Training Set in a way that yields a Data Frame again
continous_static_columns_val = pd.DataFrame(
    scaler.transform(continous_static_columns_val),
    index=continous_static_columns_val.index,
    columns=continous_static_columns_val.columns
)

# Scale Training Set in a way that yields a Data Frame again
continous_static_columns_test = pd.DataFrame(
    scaler.transform(continous_static_columns_test),
    index=continous_static_columns_test.index,
    columns=continous_static_columns_test.columns
)

# %% [markdown]
# Categorical Features

# %%
# Selecting Categorical Columns for the Different Sets
categorical_columns = ['gender', 'ethnicity', 'insurance']  
categorical_static_columns_train = static_features_train[categorical_columns]
categorical_static_columns_val = static_features_val[categorical_columns]
categorical_static_columns_test = static_features_test[categorical_columns]

# %%
# Initialize the encoder
encoder = OneHotEncoder(sparse=False, handle_unknown='ignore')

# Fit the encoder on the training data
encoder.fit(categorical_static_columns_train)

# Apply the encoder to the train, validation, and test data
categorical_static_columns_train_encoded = pd.DataFrame(
    encoder.transform(categorical_static_columns_train),
    index=categorical_static_columns_train.index,
    columns=encoder.get_feature_names_out(categorical_columns)
)

categorical_static_columns_val_encoded = pd.DataFrame(
    encoder.transform(categorical_static_columns_val),
    index=categorical_static_columns_val.index,
    columns=encoder.get_feature_names_out(categorical_columns)
)

categorical_static_columns_test_encoded = pd.DataFrame(
    encoder.transform(categorical_static_columns_test),
    index=categorical_static_columns_test.index,
    columns=encoder.get_feature_names_out(categorical_columns)
)
# Out:
# C:\Users\soere\AppData\Roaming\Python\Python311\site-packages\sklearn\preprocessing\_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %% [markdown]
# Boolean Features (ICD Codes)

# %%
# Select Boolean columns for each set (ICD Codes)
bool_static_columns_train = static_features_train[icd_features.columns]
bool_static_columns_val = static_features_val[icd_features.columns]
bool_static_columns_test = static_features_test[icd_features.columns]

# %%
# Convert Boolean Columns to Float for Consistent Formatting
bool_static_columns_train = bool_static_columns_train.astype(float)
bool_static_columns_val = bool_static_columns_val.astype(float)
bool_static_columns_test = bool_static_columns_test.astype(float)

# %% [markdown]
# Combine Data Frames Back into one per Set

# %%
# Combine all parts into one DataFrame using pd.concat
processed_static_features_train = pd.concat([continous_static_columns_train, categorical_static_columns_train_encoded, bool_static_columns_train], axis=1)
processed_static_features_test = pd.concat([continous_static_columns_test, categorical_static_columns_test_encoded, bool_static_columns_test], axis=1)
processed_static_features_val = pd.concat([continous_static_columns_val, categorical_static_columns_val_encoded, bool_static_columns_val], axis=1)

# %% [markdown]
# # Tokenization and Embedding of ICD Codes Using Med-BERT

# %% [markdown]
# Create ICD Sequences

# %%
# Function to create a sequence of ICD codes for each stay_id
def create_icd_sequence(row):
    # Filter the ICD codes that are present (value == 1.0)
    present_codes = [code for code in row.index if row[code] == 1.0]
    return ' '.join(present_codes)  # Joining codes into a single string

# Apply the function to each row and create a new DataFrame
train_icd_sequences = bool_static_columns_train.apply(create_icd_sequence, axis=1).reset_index()
train_icd_sequences.columns = ['stay_id', 'icd_sequence']

# Apply the function to each row and create a new DataFrame
val_icd_sequences = bool_static_columns_val.apply(create_icd_sequence, axis=1).reset_index()
val_icd_sequences.columns = ['stay_id', 'icd_sequence']

# Apply the function to each row and create a new DataFrame
test_icd_sequences = bool_static_columns_test.apply(create_icd_sequence, axis=1).reset_index()
test_icd_sequences.columns = ['stay_id', 'icd_sequence']

# %% [markdown]
# Oversample Minority Class

# %%
# Add label to train_icd_sequences for Oversampling
train_icd_sequences = pd.merge(labels, train_icd_sequences, on='stay_id', how='inner')

# Applying oversampling
ros = RandomOverSampler(random_state=42)
train_icd_sequences, y_resampled = ros.fit_resample(train_icd_sequences, train_icd_sequences['label'])

print(train_icd_sequences["label"].mean())
# Out:
# 0.5

# %% [markdown]
# # Tokenization

# %%
# Calculate the length of each ICD sequence
train_icd_sequences['length'] = train_icd_sequences['icd_sequence'].apply(lambda x: len(x.split()))
# Calculate the length of each ICD sequence
val_icd_sequences['length'] = val_icd_sequences['icd_sequence'].apply(lambda x: len(x.split()))
# Calculate the length of each ICD sequence
test_icd_sequences['length'] = test_icd_sequences['icd_sequence'].apply(lambda x: len(x.split()))

# Calculate percentiles
train_percentiles = np.percentile(train_icd_sequences['length'], [0, 25, 50, 75, 100])  # Modify if you need other percentiles
val_percentiles = np.percentile(val_icd_sequences['length'], [0, 25, 50, 75, 100])  # Modify if you need other percentiles
test_percentiles = np.percentile(test_icd_sequences['length'], [0, 25, 50, 75, 100])  # Modify if you need other percentiles

print("Percentiles of Training sequence lengths: 0th, 25th, 50th, 75th, 100th:", train_percentiles)
print("Percentiles of Validation sequence lengths: 0th, 25th, 50th, 75th, 100th:", val_percentiles)
print("Percentiles of Testing sequence lengths: 0th, 25th, 50th, 75th, 100th:", test_percentiles)
# Out:
# Percentiles of Training sequence lengths: 0th, 25th, 50th, 75th, 100th: [ 0. 12. 17. 23. 38.]
# Percentiles of Validation sequence lengths: 0th, 25th, 50th, 75th, 100th: [ 1. 11. 16. 21. 38.]
# Percentiles of Testing sequence lengths: 0th, 25th, 50th, 75th, 100th: [ 0. 11. 16. 21. 39.]

# %%
# Load the tokenizer for MedBERT
tokenizer = AutoTokenizer.from_pretrained('Charangan/MedBERT')

# Specify a max_length for tokenization to ensure truncation
max_length = 38  # This is the maximum length of sequences in the dataset

# Tokenize the sequences with explicit padding and truncation
tokenized_train_data = tokenizer(train_icd_sequences['icd_sequence'].tolist(),
                           padding="max_length",  # ensures all sequences are padded to the same length
                           truncation=True,       # enables truncation to max_length
                           max_length=max_length, # explicitly set max_length
                           return_tensors="pt")   # returns PyTorch tensors

tokenized_val_data = tokenizer(val_icd_sequences['icd_sequence'].tolist(),
                           padding="max_length",  # ensures all sequences are padded to the same length
                           truncation=True,       # enables truncation to max_length
                           max_length=max_length, # explicitly set max_length
                           return_tensors="pt")   # returns PyTorch tensors

tokenized_test_data = tokenizer(test_icd_sequences['icd_sequence'].tolist(),
                           padding="max_length",  # ensures all sequences are padded to the same length
                           truncation=True,       # enables truncation to max_length
                           max_length=max_length, # explicitly set max_length
                           return_tensors="pt")   # returns PyTorch tensors

# %% [markdown]
# # Embedding

# %%
# Load MedBERT model
MedBERTmodel = AutoModel.from_pretrained('Charangan/MedBERT')

# Ensure the model is in evaluation mode
MedBERTmodel.eval()

# Define input ids and attention masks
input_train_ids = tokenized_train_data['input_ids']
train_attention_mask = tokenized_train_data['attention_mask']

input_val_ids = tokenized_val_data['input_ids']
val_attention_mask = tokenized_val_data['attention_mask']

input_test_ids = tokenized_test_data['input_ids']
test_attention_mask = tokenized_test_data['attention_mask']

# Define the batch size
batch_size = 100  # Adjust this based on your available memory

# Calculate the number of batches
num_batches = (input_train_ids.size(0) + batch_size - 1) // batch_size

# List to store all embeddings
all_embeddings = []

# %%
## Embedding Generation for Training Set
# Process each batch
for i in range(num_batches):
    batch_start = i * batch_size
    batch_end = min(batch_start + batch_size, input_train_ids.size(0))
    
    # Slice the batch data
    batch_input_ids = input_train_ids[batch_start:batch_end]
    batch_attention_mask = train_attention_mask[batch_start:batch_end]

    # Forward pass to get embeddings
    with torch.no_grad():
        batch_outputs = MedBERTmodel(input_ids=batch_input_ids, attention_mask=batch_attention_mask)
        batch_embeddings = batch_outputs.last_hidden_state  # Extract embeddings
    
    # Store the embeddings
    all_embeddings.append(batch_embeddings)
    
    # Print progress
    print(f"Processed batch {i+1} of {num_batches}")

# Concatenate all embeddings to form a single tensor
train_embeddings = torch.cat(all_embeddings, dim=0)

# Now 'embeddings' contains the embeddings for the entire dataset
print("Embedding generation complete.")
# Out:
# Processed batch 1 of 153
# Processed batch 2 of 153
# Processed batch 3 of 153
# Processed batch 4 of 153
# Processed batch 5 of 153
# Processed batch 6 of 153
# Processed batch 7 of 153
# Processed batch 8 of 153
# Processed batch 9 of 153
# Processed batch 10 of 153
# Processed batch 11 of 153
# Processed batch 12 of 153
# Processed batch 13 of 153
# Processed batch 14 of 153
# Processed batch 15 of 153
# Processed batch 16 of 153
# Processed batch 17 of 153
# Processed batch 18 of 153
# Processed batch 19 of 153
# Processed batch 20 of 153
# Processed batch 21 of 153
# Processed batch 22 of 153
# Processed batch 23 of 153
# Processed batch 24 of 153
# Processed batch 25 of 153
# Processed batch 26 of 153
# Processed batch 27 of 153
# Processed batch 28 of 153
# Processed batch 29 of 153
# Processed batch 30 of 153
# Processed batch 31 of 153
# Processed batch 32 of 153
# Processed batch 33 of 153
# Processed batch 34 of 153
# Processed batch 35 of 153
# Processed batch 36 of 153
# Processed batch 37 of 153
# Processed batch 38 of 153
# Processed batch 39 of 153
# Processed batch 40 of 153
# Processed batch 41 of 153
# Processed batch 42 of 153
# Processed batch 43 of 153
# Processed batch 44 of 153
# Processed batch 45 of 153
# Processed batch 46 of 153
# Processed batch 47 of 153
# Processed batch 48 of 153
# Processed batch 49 of 153
# Processed batch 50 of 153
# Processed batch 51 of 153
# Processed batch 52 of 153
# Processed batch 53 of 153
# Processed batch 54 of 153
# Processed batch 55 of 153
# Processed batch 56 of 153
# Processed batch 57 of 153
# Processed batch 58 of 153
# Processed batch 59 of 153
# Processed batch 60 of 153
# Processed batch 61 of 153
# Processed batch 62 of 153
# Processed batch 63 of 153
# Processed batch 64 of 153
# Processed batch 65 of 153
# Processed batch 66 of 153
# Processed batch 67 of 153
# Processed batch 68 of 153
# Processed batch 69 of 153
# Processed batch 70 of 153
# Processed batch 71 of 153
# Processed batch 72 of 153
# Processed batch 73 of 153
# Processed batch 74 of 153
# Processed batch 75 of 153
# Processed batch 76 of 153
# Processed batch 77 of 153
# Processed batch 78 of 153
# Processed batch 79 of 153
# Processed batch 80 of 153
# Processed batch 81 of 153
# Processed batch 82 of 153
# Processed batch 83 of 153
# Processed batch 84 of 153
# Processed batch 85 of 153
# Processed batch 86 of 153
# Processed batch 87 of 153
# Processed batch 88 of 153
# Processed batch 89 of 153
# Processed batch 90 of 153
# Processed batch 91 of 153
# Processed batch 92 of 153
# Processed batch 93 of 153
# Processed batch 94 of 153
# Processed batch 95 of 153
# Processed batch 96 of 153
# Processed batch 97 of 153
# Processed batch 98 of 153
# Processed batch 99 of 153
# Processed batch 100 of 153
# Processed batch 101 of 153
# Processed batch 102 of 153
# Processed batch 103 of 153
# Processed batch 104 of 153
# Processed batch 105 of 153
# Processed batch 106 of 153
# Processed batch 107 of 153
# Processed batch 108 of 153
# Processed batch 109 of 153
# Processed batch 110 of 153
# Processed batch 111 of 153
# Processed batch 112 of 153
# Processed batch 113 of 153
# Processed batch 114 of 153
# Processed batch 115 of 153
# Processed batch 116 of 153
# Processed batch 117 of 153
# Processed batch 118 of 153
# Processed batch 119 of 153
# Processed batch 120 of 153
# Processed batch 121 of 153
# Processed batch 122 of 153
# Processed batch 123 of 153
# Processed batch 124 of 153
# Processed batch 125 of 153
# Processed batch 126 of 153
# Processed batch 127 of 153
# Processed batch 128 of 153
# Processed batch 129 of 153
# Processed batch 130 of 153
# Processed batch 131 of 153
# Processed batch 132 of 153
# Processed batch 133 of 153
# Processed batch 134 of 153
# Processed batch 135 of 153
# Processed batch 136 of 153
# Processed batch 137 of 153
# Processed batch 138 of 153
# Processed batch 139 of 153
# Processed batch 140 of 153
# Processed batch 141 of 153
# Processed batch 142 of 153
# Processed batch 143 of 153
# Processed batch 144 of 153
# Processed batch 145 of 153
# Processed batch 146 of 153
# Processed batch 147 of 153
# Processed batch 148 of 153
# Processed batch 149 of 153
# Processed batch 150 of 153
# Processed batch 151 of 153
# Processed batch 152 of 153
# Processed batch 153 of 153
# Embedding generation complete.

# %%
## Embedding Generation for Validation Set

all_embeddings = []  # Initialize the list to store embeddings

# Process each batch
for i in range(num_batches):
    batch_start = i * batch_size
    batch_end = min(batch_start + batch_size, input_val_ids.size(0))
    
    # Slice the batch data
    batch_input_ids = input_val_ids[batch_start:batch_end]
    batch_attention_mask = val_attention_mask[batch_start:batch_end]

    # Forward pass to get embeddings
    with torch.no_grad():
        batch_outputs = MedBERTmodel(input_ids=batch_input_ids, attention_mask=batch_attention_mask)
        batch_embeddings = batch_outputs.last_hidden_state  # Extract embeddings
    
    # Store the embeddings
    all_embeddings.append(batch_embeddings)
    
    # Print progress
    print(f"Processed batch {i+1} of {num_batches}")

# Concatenate all embeddings to form a single tensor
val_embeddings = torch.cat(all_embeddings, dim=0)

# Now 'embeddings' contains the embeddings for the entire dataset
print("Embedding generation complete.")
# Out:
# Processed batch 1 of 153
# Processed batch 2 of 153
# Processed batch 3 of 153
# Processed batch 4 of 153
# Processed batch 5 of 153
# Processed batch 6 of 153
# Processed batch 7 of 153
# Processed batch 8 of 153
# Processed batch 9 of 153
# Processed batch 10 of 153
# Processed batch 11 of 153
# Processed batch 12 of 153
# Processed batch 13 of 153
# Processed batch 14 of 153
# Processed batch 15 of 153
# Processed batch 16 of 153
# Processed batch 17 of 153
# Processed batch 18 of 153
# Processed batch 19 of 153
# Processed batch 20 of 153
# Processed batch 21 of 153
# Processed batch 22 of 153
# Processed batch 23 of 153
# Processed batch 24 of 153
# Processed batch 25 of 153
# Processed batch 26 of 153
# Processed batch 27 of 153
# Processed batch 28 of 153
# Processed batch 29 of 153
# Processed batch 30 of 153
# Processed batch 31 of 153
# Processed batch 32 of 153
# Processed batch 33 of 153
# Processed batch 34 of 153
# Processed batch 35 of 153
# Processed batch 36 of 153
# Processed batch 37 of 153
# Processed batch 38 of 153
# Processed batch 39 of 153
# Processed batch 40 of 153
# Processed batch 41 of 153
# Processed batch 42 of 153
# Processed batch 43 of 153
# Processed batch 44 of 153
# Processed batch 45 of 153
# Processed batch 46 of 153
# Processed batch 47 of 153
# Processed batch 48 of 153
# Processed batch 49 of 153
# Processed batch 50 of 153
# Processed batch 51 of 153
# Processed batch 52 of 153
# Processed batch 53 of 153
# Processed batch 54 of 153
# Processed batch 55 of 153
# Processed batch 56 of 153
# Processed batch 57 of 153
# Processed batch 58 of 153
# Processed batch 59 of 153
# Processed batch 60 of 153
# Processed batch 61 of 153
# Processed batch 62 of 153
# Processed batch 63 of 153
# Processed batch 64 of 153
# Processed batch 65 of 153
# Processed batch 66 of 153
# Processed batch 67 of 153
# Processed batch 68 of 153
# Processed batch 69 of 153
# Processed batch 70 of 153
# Processed batch 71 of 153
# Processed batch 72 of 153
# Processed batch 73 of 153
# Processed batch 74 of 153
# Processed batch 75 of 153
# Processed batch 76 of 153
# Processed batch 77 of 153
# Processed batch 78 of 153
# Processed batch 79 of 153
# Processed batch 80 of 153
# Processed batch 81 of 153
# Processed batch 82 of 153
# Processed batch 83 of 153
# Processed batch 84 of 153
# Processed batch 85 of 153
# Processed batch 86 of 153
# Processed batch 87 of 153
# Processed batch 88 of 153
# Processed batch 89 of 153
# Processed batch 90 of 153
# Processed batch 91 of 153
# Processed batch 92 of 153
# Processed batch 93 of 153
# Processed batch 94 of 153
# Processed batch 95 of 153
# Processed batch 96 of 153
# Processed batch 97 of 153
# Processed batch 98 of 153
# Processed batch 99 of 153
# Processed batch 100 of 153
# Processed batch 101 of 153
# Processed batch 102 of 153
# Processed batch 103 of 153
# Processed batch 104 of 153
# Processed batch 105 of 153
# Processed batch 106 of 153
# Processed batch 107 of 153
# Processed batch 108 of 153
# Processed batch 109 of 153
# Processed batch 110 of 153
# Processed batch 111 of 153
# Processed batch 112 of 153
# Processed batch 113 of 153
# Processed batch 114 of 153
# Processed batch 115 of 153
# Processed batch 116 of 153
# Processed batch 117 of 153
# Processed batch 118 of 153
# Processed batch 119 of 153
# Processed batch 120 of 153
# Processed batch 121 of 153
# Processed batch 122 of 153
# Processed batch 123 of 153
# Processed batch 124 of 153
# Processed batch 125 of 153
# Processed batch 126 of 153
# Processed batch 127 of 153
# Processed batch 128 of 153
# Processed batch 129 of 153
# Processed batch 130 of 153
# Processed batch 131 of 153
# Processed batch 132 of 153
# Processed batch 133 of 153
# Processed batch 134 of 153
# Processed batch 135 of 153
# Processed batch 136 of 153
# Processed batch 137 of 153
# Processed batch 138 of 153
# Processed batch 139 of 153
# Processed batch 140 of 153
# Processed batch 141 of 153
# Processed batch 142 of 153
# Processed batch 143 of 153
# Processed batch 144 of 153
# Processed batch 145 of 153
# Processed batch 146 of 153
# Processed batch 147 of 153
# Processed batch 148 of 153
# Processed batch 149 of 153
# Processed batch 150 of 153
# Processed batch 151 of 153
# Processed batch 152 of 153
# Processed batch 153 of 153
# Embedding generation complete.

# %%
## Embedding Generation for Testing Set

all_embeddings = []  # Initialize the list to store embeddings

# Process each batch
for i in range(num_batches):
    batch_start = i * batch_size
    batch_end = min(batch_start + batch_size, input_test_ids.size(0))
    
    # Slice the batch data
    batch_input_ids = input_test_ids[batch_start:batch_end]
    batch_attention_mask = test_attention_mask[batch_start:batch_end]

    # Forward pass to get embeddings
    with torch.no_grad():
        batch_outputs = MedBERTmodel(input_ids=batch_input_ids, attention_mask=batch_attention_mask)
        batch_embeddings = batch_outputs.last_hidden_state  # Extract embeddings
    
    # Store the embeddings
    all_embeddings.append(batch_embeddings)
    
    # Print progress
    print(f"Processed batch {i+1} of {num_batches}")

# Concatenate all embeddings to form a single tensor
test_embeddings = torch.cat(all_embeddings, dim=0)

# Now 'embeddings' contains the embeddings for the entire dataset
print("Embedding generation complete.")
# Out:
# Processed batch 1 of 153
# Processed batch 2 of 153
# Processed batch 3 of 153
# Processed batch 4 of 153
# Processed batch 5 of 153
# Processed batch 6 of 153
# Processed batch 7 of 153
# Processed batch 8 of 153
# Processed batch 9 of 153
# Processed batch 10 of 153
# Processed batch 11 of 153
# Processed batch 12 of 153
# Processed batch 13 of 153
# Processed batch 14 of 153
# Processed batch 15 of 153
# Processed batch 16 of 153
# Processed batch 17 of 153
# Processed batch 18 of 153
# Processed batch 19 of 153
# Processed batch 20 of 153
# Processed batch 21 of 153
# Processed batch 22 of 153
# Processed batch 23 of 153
# Processed batch 24 of 153
# Processed batch 25 of 153
# Processed batch 26 of 153
# Processed batch 27 of 153
# Processed batch 28 of 153
# Processed batch 29 of 153
# Processed batch 30 of 153
# Processed batch 31 of 153
# Processed batch 32 of 153
# Processed batch 33 of 153
# Processed batch 34 of 153
# Processed batch 35 of 153
# Processed batch 36 of 153
# Processed batch 37 of 153
# Processed batch 38 of 153
# Processed batch 39 of 153
# Processed batch 40 of 153
# Processed batch 41 of 153
# Processed batch 42 of 153
# Processed batch 43 of 153
# Processed batch 44 of 153
# Processed batch 45 of 153
# Processed batch 46 of 153
# Processed batch 47 of 153
# Processed batch 48 of 153
# Processed batch 49 of 153
# Processed batch 50 of 153
# Processed batch 51 of 153
# Processed batch 52 of 153
# Processed batch 53 of 153
# Processed batch 54 of 153
# Processed batch 55 of 153
# Processed batch 56 of 153
# Processed batch 57 of 153
# Processed batch 58 of 153
# Processed batch 59 of 153
# Processed batch 60 of 153
# Processed batch 61 of 153
# Processed batch 62 of 153
# Processed batch 63 of 153
# Processed batch 64 of 153
# Processed batch 65 of 153
# Processed batch 66 of 153
# Processed batch 67 of 153
# Processed batch 68 of 153
# Processed batch 69 of 153
# Processed batch 70 of 153
# Processed batch 71 of 153
# Processed batch 72 of 153
# Processed batch 73 of 153
# Processed batch 74 of 153
# Processed batch 75 of 153
# Processed batch 76 of 153
# Processed batch 77 of 153
# Processed batch 78 of 153
# Processed batch 79 of 153
# Processed batch 80 of 153
# Processed batch 81 of 153
# Processed batch 82 of 153
# Processed batch 83 of 153
# Processed batch 84 of 153
# Processed batch 85 of 153
# Processed batch 86 of 153
# Processed batch 87 of 153
# Processed batch 88 of 153
# Processed batch 89 of 153
# Processed batch 90 of 153
# Processed batch 91 of 153
# Processed batch 92 of 153
# Processed batch 93 of 153
# Processed batch 94 of 153
# Processed batch 95 of 153
# Processed batch 96 of 153
# Processed batch 97 of 153
# Processed batch 98 of 153
# Processed batch 99 of 153
# Processed batch 100 of 153
# Processed batch 101 of 153
# Processed batch 102 of 153
# Processed batch 103 of 153
# Processed batch 104 of 153
# Processed batch 105 of 153
# Processed batch 106 of 153
# Processed batch 107 of 153
# Processed batch 108 of 153
# Processed batch 109 of 153
# Processed batch 110 of 153
# Processed batch 111 of 153
# Processed batch 112 of 153
# Processed batch 113 of 153
# Processed batch 114 of 153
# Processed batch 115 of 153
# Processed batch 116 of 153
# Processed batch 117 of 153
# Processed batch 118 of 153
# Processed batch 119 of 153
# Processed batch 120 of 153
# Processed batch 121 of 153
# Processed batch 122 of 153
# Processed batch 123 of 153
# Processed batch 124 of 153
# Processed batch 125 of 153
# Processed batch 126 of 153
# Processed batch 127 of 153
# Processed batch 128 of 153
# Processed batch 129 of 153
# Processed batch 130 of 153
# Processed batch 131 of 153
# Processed batch 132 of 153
# Processed batch 133 of 153
# Processed batch 134 of 153
# Processed batch 135 of 153
# Processed batch 136 of 153
# Processed batch 137 of 153
# Processed batch 138 of 153
# Processed batch 139 of 153
# Processed batch 140 of 153
# Processed batch 141 of 153
# Processed batch 142 of 153
# Processed batch 143 of 153
# Processed batch 144 of 153
# Processed batch 145 of 153
# Processed batch 146 of 153
# Processed batch 147 of 153
# Processed batch 148 of 153
# Processed batch 149 of 153
# Processed batch 150 of 153
# Processed batch 151 of 153
# Processed batch 152 of 153
# Processed batch 153 of 153
# Embedding generation complete.

# %%
print("Train Embedding Shape:", train_embeddings.shape)
print("Validation Embedding Shape:", val_embeddings.shape)
print("Test Embedding Shape:", test_embeddings.shape)
# Out:
# Train Embedding Shape: torch.Size([15274, 38, 768])
# Validation Embedding Shape: torch.Size([1785, 38, 768])
# Test Embedding Shape: torch.Size([1784, 38, 768])

# %% [markdown]
# # Define Label Tensors

# %%
# Convert label columns directly to tensors
label_tensor_train = torch.tensor(train_icd_sequences['label'].values, dtype=torch.float32)
label_tensor_test = torch.tensor(test_stays['label'].values, dtype=torch.float32)
label_tensor_val = torch.tensor(val_stays['label'].values, dtype=torch.float32)

# Print shapes to confirm
print("Label Train Tensor shape:", label_tensor_train.shape)
print("Label Test Tensor shape:", label_tensor_test.shape)
print("Label Validation Tensor shape:", label_tensor_val.shape)
# Out:
# Label Train Tensor shape: torch.Size([15274])
# Label Test Tensor shape: torch.Size([1784])
# Label Validation Tensor shape: torch.Size([1785])

# %% [markdown]
# # Train Model on the Embeddings

# %%
# Define a simple feedforward neural network
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(768, 128)  # Input Feaeture Size has to match embedding size
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(128, 1)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        x = self.relu(self.fc1(x))
        x = self.sigmoid(self.fc2(x))
        return x

# Instantiate the model
model = Net()

# Verify dimensions of embeddings before training
print("Before Averaging - Train Embedding Shape:", train_embeddings.shape)
print("Before Averaging - Validation Embedding Shape:", val_embeddings.shape)

# If not already averaged (checking if it's necessary)
if train_embeddings.dim() > 2:
    train_embeddings = torch.mean(train_embeddings, dim=1)
    val_embeddings = torch.mean(val_embeddings, dim=1)

print("After Averaging - Train Embedding Shape:", train_embeddings.shape)
print("After Averaging - Validation Embedding Shape:", val_embeddings.shape)

# Define the loss function and optimizer
criterion = nn.BCELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Training function
def train_model(model, criterion, optimizer, train_data, train_labels, val_data, val_labels, epochs=100):
    best_val_loss = float('inf')
    for epoch in range(epochs):
        model.train()
        optimizer.zero_grad()
        
        # Forward pass
        outputs = model(train_data)
        loss = criterion(outputs.squeeze(), train_labels)
        
        # Backward and optimize
        loss.backward()
        optimizer.step()
        
        # Evaluate on validation data
        model.eval()
        with torch.no_grad():
            val_outputs = model(val_data)
            val_loss = criterion(val_outputs.squeeze(), val_labels)
            
            # Check if current validation loss is lower, and if so, save the model
            if val_loss < best_val_loss:
                best_val_loss = val_loss
                torch.save(model.state_dict(), './saved_models/Med-BERT/state_dict/best_model.pth')
            
            print(f'Epoch [{epoch+1}/{epochs}], Loss: {loss.item():.4f}, Val Loss: {val_loss.item():.4f}')

    print("Best Validation Loss:", best_val_loss)
            
# Train the model
train_model(model, criterion, optimizer, train_embeddings, label_tensor_train, val_embeddings, label_tensor_val)
# Out:
# Before Averaging - Train Embedding Shape: torch.Size([15274, 38, 768])
# Before Averaging - Validation Embedding Shape: torch.Size([1785, 38, 768])
# After Averaging - Train Embedding Shape: torch.Size([15274, 768])
# After Averaging - Validation Embedding Shape: torch.Size([1785, 768])
# Epoch [1/100], Loss: 0.6970, Val Loss: 0.8051
# Epoch [2/100], Loss: 0.6901, Val Loss: 0.7077
# Epoch [3/100], Loss: 0.6752, Val Loss: 0.6169
# Epoch [4/100], Loss: 0.6704, Val Loss: 0.6084
# Epoch [5/100], Loss: 0.6628, Val Loss: 0.6506
# Epoch [6/100], Loss: 0.6532, Val Loss: 0.6919
# Epoch [7/100], Loss: 0.6483, Val Loss: 0.6878
# Epoch [8/100], Loss: 0.6429, Val Loss: 0.6415
# Epoch [9/100], Loss: 0.6367, Val Loss: 0.5965
# Epoch [10/100], Loss: 0.6336, Val Loss: 0.5920
# Epoch [11/100], Loss: 0.6297, Val Loss: 0.6208
# Epoch [12/100], Loss: 0.6248, Val Loss: 0.6488
# Epoch [13/100], Loss: 0.6218, Val Loss: 0.6434
# Epoch [14/100], Loss: 0.6179, Val Loss: 0.6099
# Epoch [15/100], Loss: 0.6131, Val Loss: 0.5799
# Epoch [16/100], Loss: 0.6096, Val Loss: 0.5773
# Epoch [65/100], Loss: 0.4825, Val Loss: 0.4920
# Epoch [66/100], Loss: 0.4810, Val Loss: 0.4793
# Epoch [67/100], Loss: 0.4795, Val Loss: 0.4922
# Epoch [68/100], Loss: 0.4780, Val Loss: 0.4744
# Epoch [69/100], Loss: 0.4766, Val Loss: 0.4938
# Epoch [70/100], Loss: 0.4752, Val Loss: 0.4658
# Epoch [71/100], Loss: 0.4739, Val Loss: 0.5001
# Epoch [72/100], Loss: 0.4727, Val Loss: 0.4536
# Epoch [73/100], Loss: 0.4717, Val Loss: 0.5086
# Epoch [74/100], Loss: 0.4707, Val Loss: 0.4493
# Epoch [75/100], Loss: 0.4693, Val Loss: 0.4950
# Epoch [76/100], Loss: 0.4675, Val Loss: 0.4706
# Epoch [77/100], Loss: 0.4659, Val Loss: 0.4632
# Epoch [78/100], Loss: 0.4649, Val Loss: 0.4951
# Epoch [79/100], Loss: 0.4642, Val Loss: 0.4481
# Epoch [80/100], Loss: 0.4633, Val Loss: 0.4931
# Epoch [81/100], Loss: 0.4620, Val Loss: 0.4604
# Epoch [82/100], Loss: 0.4604, Val Loss: 0.4673
# Epoch [83/100], Loss: 0.4593, Val Loss: 0.4828
# Epoch [84/100], Loss: 0.4585, Val Loss: 0.4490
# Epoch [85/100], Loss: 0.4577, Val Loss: 0.4901
# Epoch [86/100], Loss: 0.4568, Val Loss: 0.4496
# Epoch [87/100], Loss: 0.4556, Val Loss: 0.4765
# Epoch [88/100], Loss: 0.4544, Val Loss: 0.4649
# Epoch [89/100], Loss: 0.4533, Val Loss: 0.4570
# Epoch [90/100], Loss: 0.4524, Val Loss: 0.4798
# Epoch [91/100], Loss: 0.4517, Val Loss: 0.4448
# Epoch [92/100], Loss: 0.4510, Val Loss: 0.4858
# Epoch [93/100], Loss: 0.4503, Val Loss: 0.4421
# Epoch [94/100], Loss: 0.4493, Val Loss: 0.4793
# Epoch [95/100], Loss: 0.4483, Val Loss: 0.4512
# Epoch [96/100], Loss: 0.4472, Val Loss: 0.4652
# Epoch [97/100], Loss: 0.4462, Val Loss: 0.4629
# Epoch [98/100], Loss: 0.4453, Val Loss: 0.4515
# Epoch [99/100], Loss: 0.4446, Val Loss: 0.4734
# Epoch [100/100], Loss: 0.4439, Val Loss: 0.4404
# Best Validation Loss: tensor(0.4404)

# %%
# Check if averaging is needed
if test_embeddings.dim() > 2:
    test_embeddings = torch.mean(test_embeddings, dim=1)

# Load best version of the model
model.load_state_dict(torch.load('./saved_models/Med-BERT/state_dict/best_model.pth'))
# Out:
# <All keys matched successfully>

# %%
def evaluate_model(model, test_embeddings, label_tensor_test, directory, model_name, beta=2):
    # Ensure the model is in evaluation mode
    model.eval()
    sns.set()  # For better plot styling

    # Predict on the test set
    with torch.no_grad():
        test_outputs = model(test_embeddings).squeeze()
        test_probs = test_outputs.numpy()

    # True labels for comparison
    true_labels = label_tensor_test.numpy()

    # Calculate precision-recall curve and corresponding thresholds
    precision, recall, thresholds = precision_recall_curve(true_labels, test_probs)

    # Calculate F-beta scores for each possible threshold
    f_beta_scores = (1 + beta**2) * (precision * recall) / ((beta**2 * precision) + recall)
    f_beta_scores = np.nan_to_num(f_beta_scores)  # Handling NaNs

    # Find the threshold that maximizes the F-beta score
    optimal_idx = np.argmax(f_beta_scores)
    best_threshold = thresholds[optimal_idx]

    # Use the best threshold found
    test_predictions = (test_probs > best_threshold).astype(int)

    # Calculate metrics
    accuracy = accuracy_score(true_labels, test_predictions)
    precision = precision_score(true_labels, test_predictions, zero_division=0)
    recall = recall_score(true_labels, test_predictions)
    f1 = f1_score(true_labels, test_predictions)
    auc_roc = roc_auc_score(true_labels, test_probs)
    auprc = average_precision_score(true_labels, test_probs)

    # Print the results
    print(f"Best Threshold: {best_threshold:.2f}")
    print(f"{model_name} Model Performance on Test Set:")
    print(f"Accuracy: {accuracy:.2f}")
    print(f"Precision: {precision:.2f}")
    print(f"Recall: {recall:.2f}")
    print(f"F1 Score: {f1:.2f}")
    print(f"AUC-ROC: {auc_roc:.2f}")
    print(f"AUPRC: {auprc:.2f}")

    # Ensure the directory exists
    if not os.path.exists(directory):
        os.makedirs(directory)

    # Save the confusion matrix
    cm = confusion_matrix(true_labels, test_predictions)
    plt.figure(figsize=(6, 4))
    sns.heatmap(cm, annot=True, fmt="d", cmap='Blues')
    plt.title(f'Confusion Matrix - {model_name} - Trained on {percentage}')
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.tight_layout()
    plt.savefig(f'{directory}/{model_name}_confusion_matrix.png')
    plt.close()  # Close the plot to avoid display

    # Save performance metrics to a text file
    metrics_filepath = f'{directory}/{model_name}_metrics.txt'
    with open(metrics_filepath, 'w') as f:
        f.write(f"{model_name} Model Performance on Test Set:\n")
        f.write(f"Best Threshold: {best_threshold:.2f}\n")
        f.write(f"Accuracy: {accuracy:.2f}\n")
        f.write(f"Precision: {precision:.2f}\n")
        f.write(f"Recall: {recall:.2f}\n")
        f.write(f"F1 Score: {f1:.2f}\n")
        f.write(f"AUC-ROC: {auc_roc:.2f}\n")
        f.write(f"AUPRC: {auprc:.2f}\n")

    print(f"Performance metrics saved to: {metrics_filepath}")

# %%
# Directory where you want to save outputs
output_directory = f'./saved_models/MED-BERT/trained_on_{percentage}'
model_name = 'Med-BERT'  # Name of the model, used for saving outputs

# Call the evaluate function
evaluate_model(model, test_embeddings, label_tensor_test, output_directory, model_name, beta=2)
# Out:
# Best Threshold: 0.47
# Med-BERT Model Performance on Test Set:
# Accuracy: 0.76
# Precision: 0.22
# Recall: 0.76
# F1 Score: 0.35
# AUC-ROC: 0.83
# AUPRC: 0.32
# Performance metrics saved to: ./saved_models/MED-BERT/trained_on_25%/Med-BERT_metrics.txt
# C:\Users\soere\AppData\Local\Temp\ipykernel_27316\1698379808.py:18: RuntimeWarning: invalid value encountered in divide
#   f_beta_scores = (1 + beta**2) * (precision * recall) / ((beta**2 * precision) + recall)

# %%
# Save model and optimizer state
torch.save({
    'model_state_dict': model.state_dict(),
    'optimizer_state_dict': optimizer.state_dict(),
}, f'./saved_models/Med-BERT/trained_on_{percentage}/best-Med-BERT-model.pth')

# %% [markdown]
# # Hyperparameter Tuning

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from itertools import product
from sklearn.metrics import roc_auc_score
import numpy as np

# Define the Neural Network model
class Net(nn.Module):
    def __init__(self, hidden_units=128):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(768, hidden_units)
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(hidden_units, 1)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        x = self.relu(self.fc1(x))
        x = self.sigmoid(self.fc2(x))
        return x

# Helper function for training and evaluating the model
def train_and_evaluate(model, train_data, train_labels, val_data, val_labels, optimizer, criterion, epochs):
    best_auc_roc = 0
    best_model_wts = None
    for epoch in range(epochs):
        model.train()
        optimizer.zero_grad()
        outputs = model(train_data)
        loss = criterion(outputs.squeeze(), train_labels)
        loss.backward()
        optimizer.step()

        model.eval()
        with torch.no_grad():
            val_outputs = model(val_data)
            val_preds = val_outputs.squeeze().cpu().numpy()
            val_auc_roc = roc_auc_score(val_labels.cpu().numpy(), val_preds)
            if val_auc_roc > best_auc_roc:
                best_auc_roc = val_auc_roc
                best_model_wts = model.state_dict()

        print(f'Epoch {epoch + 1}/{epochs}, Loss: {loss.item():.4f}, Val AUC-ROC: {val_auc_roc:.4f}')

    return best_auc_roc, best_model_wts

# Hyperparameter Tuning function
def hyperparameter_tuning(train_data, train_labels, val_data, val_labels, param_grid):
    best_auc_roc = 0
    best_params = {}
    best_model = None

    for hidden_units, lr in product(param_grid['hidden_units'], param_grid['learning_rate']):
        print(f"Testing configuration: Hidden Units: {hidden_units}, Learning Rate: {lr}")
        
        model = Net(hidden_units=hidden_units)
        optimizer = optim.Adam(model.parameters(), lr=lr)
        criterion = nn.BCELoss()
        
        auc_roc, best_model_wts = train_and_evaluate(model, train_data, train_labels, val_data, val_labels, optimizer, criterion, epochs=50)
        
        if auc_roc > best_auc_roc:
            best_auc_roc = auc_roc
            best_params = {'hidden_units': hidden_units, 'learning_rate': lr}
            best_model = model
            best_model.load_state_dict(best_model_wts)
            print(f"New best model found with AUC-ROC: {auc_roc:.4f}")

    if best_params:
        print("Best Model Parameters:", best_params)
        print("Best Model AUC-ROC:", best_auc_roc)
    else:
        print("No improvement found with hyperparameter tuning.")

    return best_model, best_params

# Define the parameter grid
param_grid = {
    'hidden_units': [8, 16, 32 ,64, 128],
    'learning_rate': [0.5, 0.1, 0.01, 0.001, 0.0001]
}

# Start the hyperparameter tuning process
best_model, best_params = hyperparameter_tuning(train_embeddings, label_tensor_train, val_embeddings, label_tensor_val, param_grid)
# Out:
# Testing configuration: Hidden Units: 8, Learning Rate: 0.5
# Epoch 1/50, Loss: 0.7049, Val AUC-ROC: 0.5542
# Epoch 2/50, Loss: 44.3974, Val AUC-ROC: 0.5000
# Epoch 3/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 4/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 5/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 6/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 7/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 8/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 9/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 10/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 11/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 12/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 13/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 14/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 15/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 16/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 17/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 18/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 19/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 20/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 21/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 22/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 23/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 24/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 25/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 26/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 27/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 28/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 29/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 30/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 31/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 32/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 33/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 34/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 35/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 36/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 37/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 38/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 39/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 40/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 41/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 42/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 43/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 44/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 45/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 46/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 47/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 48/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 49/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 50/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# New best model found with AUC-ROC: 0.5542
# Testing configuration: Hidden Units: 8, Learning Rate: 0.1
# Epoch 1/50, Loss: 0.7044, Val AUC-ROC: 0.6078
# Epoch 2/50, Loss: 3.9429, Val AUC-ROC: 0.6427
# Epoch 3/50, Loss: 0.7350, Val AUC-ROC: 0.4289
# Epoch 4/50, Loss: 0.7266, Val AUC-ROC: 0.4954
# Epoch 5/50, Loss: 0.7118, Val AUC-ROC: 0.5008
# Epoch 6/50, Loss: 0.7132, Val AUC-ROC: 0.5000
# Epoch 7/50, Loss: 0.7145, Val AUC-ROC: 0.5000
# Epoch 8/50, Loss: 0.7148, Val AUC-ROC: 0.5000
# Epoch 9/50, Loss: 0.7141, Val AUC-ROC: 0.5000
# Epoch 10/50, Loss: 0.7126, Val AUC-ROC: 0.5000
# Epoch 11/50, Loss: 0.7107, Val AUC-ROC: 0.5000
# Epoch 12/50, Loss: 0.7083, Val AUC-ROC: 0.5000
# Epoch 13/50, Loss: 0.7059, Val AUC-ROC: 0.5000
# Epoch 14/50, Loss: 0.7034, Val AUC-ROC: 0.5000
# Epoch 15/50, Loss: 0.7010, Val AUC-ROC: 0.5000
# Epoch 16/50, Loss: 0.6989, Val AUC-ROC: 0.5000
# Epoch 17/50, Loss: 0.6971, Val AUC-ROC: 0.5000
# Epoch 18/50, Loss: 0.6956, Val AUC-ROC: 0.5000
# Epoch 19/50, Loss: 0.6945, Val AUC-ROC: 0.5000
# Epoch 20/50, Loss: 0.6937, Val AUC-ROC: 0.5000
# Epoch 21/50, Loss: 0.6933, Val AUC-ROC: 0.5000
# Epoch 22/50, Loss: 0.6931, Val AUC-ROC: 0.5000
# Epoch 23/50, Loss: 0.6932, Val AUC-ROC: 0.5000
# Epoch 24/50, Loss: 0.6935, Val AUC-ROC: 0.5000
# Epoch 25/50, Loss: 0.6938, Val AUC-ROC: 0.5000
# Epoch 26/50, Loss: 0.6942, Val AUC-ROC: 0.5000
# Epoch 27/50, Loss: 0.6946, Val AUC-ROC: 0.5000
# Epoch 28/50, Loss: 0.6949, Val AUC-ROC: 0.5000
# Epoch 29/50, Loss: 0.6951, Val AUC-ROC: 0.5000
# Epoch 30/50, Loss: 0.6952, Val AUC-ROC: 0.5000
# Epoch 31/50, Loss: 0.6952, Val AUC-ROC: 0.5000
# Epoch 32/50, Loss: 0.6952, Val AUC-ROC: 0.5000
# Epoch 33/50, Loss: 0.6950, Val AUC-ROC: 0.5000
# Epoch 34/50, Loss: 0.6948, Val AUC-ROC: 0.5000
# Epoch 35/50, Loss: 0.6945, Val AUC-ROC: 0.5000
# Epoch 36/50, Loss: 0.6942, Val AUC-ROC: 0.5000
# Epoch 37/50, Loss: 0.6940, Val AUC-ROC: 0.5000
# Epoch 38/50, Loss: 0.6937, Val AUC-ROC: 0.5000
# Epoch 39/50, Loss: 0.6935, Val AUC-ROC: 0.5000
# Epoch 40/50, Loss: 0.6933, Val AUC-ROC: 0.5000
# Epoch 41/50, Loss: 0.6932, Val AUC-ROC: 0.5000
# Epoch 42/50, Loss: 0.6932, Val AUC-ROC: 0.5000
# Epoch 43/50, Loss: 0.6931, Val AUC-ROC: 0.5000
# Epoch 44/50, Loss: 0.6932, Val AUC-ROC: 0.5000
# Epoch 45/50, Loss: 0.6932, Val AUC-ROC: 0.5000
# Epoch 46/50, Loss: 0.6933, Val AUC-ROC: 0.5000
# Epoch 47/50, Loss: 0.6933, Val AUC-ROC: 0.5000
# Epoch 48/50, Loss: 0.6934, Val AUC-ROC: 0.5000
# Epoch 49/50, Loss: 0.6934, Val AUC-ROC: 0.5000
# Epoch 50/50, Loss: 0.6934, Val AUC-ROC: 0.5000
# New best model found with AUC-ROC: 0.6427
# Testing configuration: Hidden Units: 8, Learning Rate: 0.01
# Epoch 1/50, Loss: 0.6971, Val AUC-ROC: 0.6568
# Epoch 2/50, Loss: 0.7167, Val AUC-ROC: 0.6687
# Epoch 3/50, Loss: 0.6830, Val AUC-ROC: 0.6407
# Epoch 4/50, Loss: 0.6928, Val AUC-ROC: 0.6724
# Epoch 5/50, Loss: 0.6890, Val AUC-ROC: 0.6788
# Epoch 6/50, Loss: 0.6724, Val AUC-ROC: 0.6777
# Epoch 7/50, Loss: 0.6644, Val AUC-ROC: 0.6777
# Epoch 8/50, Loss: 0.6636, Val AUC-ROC: 0.6740
# Epoch 34/50, Loss: 0.6864, Val AUC-ROC: 0.6606
# Epoch 35/50, Loss: 0.6862, Val AUC-ROC: 0.6619
# Epoch 36/50, Loss: 0.6860, Val AUC-ROC: 0.6627
# Epoch 37/50, Loss: 0.6858, Val AUC-ROC: 0.6633
# Epoch 38/50, Loss: 0.6856, Val AUC-ROC: 0.6646
# Epoch 39/50, Loss: 0.6854, Val AUC-ROC: 0.6656
# Epoch 40/50, Loss: 0.6852, Val AUC-ROC: 0.6659
# Epoch 41/50, Loss: 0.6850, Val AUC-ROC: 0.6665
# Epoch 42/50, Loss: 0.6848, Val AUC-ROC: 0.6674
# Epoch 43/50, Loss: 0.6845, Val AUC-ROC: 0.6684
# Epoch 44/50, Loss: 0.6843, Val AUC-ROC: 0.6693
# Epoch 45/50, Loss: 0.6841, Val AUC-ROC: 0.6693
# Epoch 46/50, Loss: 0.6838, Val AUC-ROC: 0.6704
# Epoch 47/50, Loss: 0.6836, Val AUC-ROC: 0.6713
# Epoch 48/50, Loss: 0.6833, Val AUC-ROC: 0.6724
# Epoch 49/50, Loss: 0.6830, Val AUC-ROC: 0.6728
# Epoch 50/50, Loss: 0.6827, Val AUC-ROC: 0.6738
# Testing configuration: Hidden Units: 16, Learning Rate: 0.5
# Epoch 1/50, Loss: 0.6932, Val AUC-ROC: 0.6650
# Epoch 2/50, Loss: 23.0265, Val AUC-ROC: 0.5000
# Epoch 3/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 4/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 5/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 6/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 7/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 8/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 9/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 10/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 11/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 12/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 13/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 14/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 15/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 16/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 17/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 18/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 19/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 20/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 21/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 22/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 23/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 24/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 25/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 26/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 27/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 28/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 29/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 30/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 31/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 32/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 33/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 34/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 35/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 36/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 37/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 38/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 39/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 40/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 41/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 42/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 43/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 44/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 45/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 46/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 47/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 48/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 49/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 50/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Testing configuration: Hidden Units: 16, Learning Rate: 0.1
# Epoch 1/50, Loss: 0.6948, Val AUC-ROC: 0.6510
# Epoch 2/50, Loss: 11.6043, Val AUC-ROC: 0.6612
# Epoch 3/50, Loss: 0.9347, Val AUC-ROC: 0.5015
# Epoch 4/50, Loss: 0.6979, Val AUC-ROC: 0.5000
# Epoch 5/50, Loss: 0.7023, Val AUC-ROC: 0.5000
# Epoch 6/50, Loss: 0.7056, Val AUC-ROC: 0.5000
# Epoch 7/50, Loss: 0.7081, Val AUC-ROC: 0.5000
# Epoch 8/50, Loss: 0.7098, Val AUC-ROC: 0.5000
# Epoch 9/50, Loss: 0.7106, Val AUC-ROC: 0.5000
# Epoch 10/50, Loss: 0.7107, Val AUC-ROC: 0.5000
# Epoch 11/50, Loss: 0.7101, Val AUC-ROC: 0.5000
# Epoch 12/50, Loss: 0.7089, Val AUC-ROC: 0.5000
# Epoch 13/50, Loss: 0.7074, Val AUC-ROC: 0.5000
# Epoch 14/50, Loss: 0.7055, Val AUC-ROC: 0.5000
# Epoch 15/50, Loss: 0.7036, Val AUC-ROC: 0.5000
# Epoch 16/50, Loss: 0.7016, Val AUC-ROC: 0.5000
# Epoch 17/50, Loss: 0.6997, Val AUC-ROC: 0.5000
# Epoch 18/50, Loss: 0.6980, Val AUC-ROC: 0.5000
# Epoch 19/50, Loss: 0.6965, Val AUC-ROC: 0.5000
# Epoch 20/50, Loss: 0.6953, Val AUC-ROC: 0.5000
# Epoch 21/50, Loss: 0.6943, Val AUC-ROC: 0.5000
# Epoch 22/50, Loss: 0.6937, Val AUC-ROC: 0.5000
# Epoch 23/50, Loss: 0.6933, Val AUC-ROC: 0.5000
# Epoch 24/50, Loss: 0.6932, Val AUC-ROC: 0.5000
# Epoch 25/50, Loss: 0.6932, Val AUC-ROC: 0.5000
# Epoch 26/50, Loss: 0.6934, Val AUC-ROC: 0.5000
# Epoch 27/50, Loss: 0.6936, Val AUC-ROC: 0.5000
# Epoch 28/50, Loss: 0.6939, Val AUC-ROC: 0.5000
# Epoch 29/50, Loss: 0.6942, Val AUC-ROC: 0.5000
# Epoch 30/50, Loss: 0.6945, Val AUC-ROC: 0.5000
# Epoch 31/50, Loss: 0.6947, Val AUC-ROC: 0.5000
# Epoch 32/50, Loss: 0.6948, Val AUC-ROC: 0.5000
# Epoch 33/50, Loss: 0.6948, Val AUC-ROC: 0.5000
# Epoch 34/50, Loss: 0.6948, Val AUC-ROC: 0.5000
# Epoch 35/50, Loss: 0.6947, Val AUC-ROC: 0.5000
# Epoch 36/50, Loss: 0.6945, Val AUC-ROC: 0.5000
# Epoch 37/50, Loss: 0.6943, Val AUC-ROC: 0.5000
# Epoch 38/50, Loss: 0.6941, Val AUC-ROC: 0.5000
# Epoch 39/50, Loss: 0.6939, Val AUC-ROC: 0.5000
# Epoch 40/50, Loss: 0.6937, Val AUC-ROC: 0.5000
# Epoch 41/50, Loss: 0.6935, Val AUC-ROC: 0.5000
# Epoch 42/50, Loss: 0.6934, Val AUC-ROC: 0.5000
# Epoch 43/50, Loss: 0.6932, Val AUC-ROC: 0.5000
# Epoch 44/50, Loss: 0.6932, Val AUC-ROC: 0.5000
# Epoch 45/50, Loss: 0.6932, Val AUC-ROC: 0.5000
# Epoch 46/50, Loss: 0.6932, Val AUC-ROC: 0.5000
# Epoch 47/50, Loss: 0.6932, Val AUC-ROC: 0.5000
# Epoch 48/50, Loss: 0.6932, Val AUC-ROC: 0.5000
# Epoch 49/50, Loss: 0.6933, Val AUC-ROC: 0.5000
# Epoch 50/50, Loss: 0.6933, Val AUC-ROC: 0.5000
# Testing configuration: Hidden Units: 16, Learning Rate: 0.01
# Epoch 1/50, Loss: 0.6951, Val AUC-ROC: 0.6619
# Epoch 2/50, Loss: 0.7363, Val AUC-ROC: 0.6476
# Epoch 3/50, Loss: 0.6861, Val AUC-ROC: 0.5937
# Epoch 4/50, Loss: 0.6908, Val AUC-ROC: 0.5641
# Epoch 5/50, Loss: 0.6916, Val AUC-ROC: 0.5580
# Epoch 6/50, Loss: 0.6917, Val AUC-ROC: 0.5611
# Epoch 7/50, Loss: 0.6914, Val AUC-ROC: 0.5733
# Epoch 8/50, Loss: 0.6910, Val AUC-ROC: 0.5715
# Epoch 9/50, Loss: 0.6903, Val AUC-ROC: 0.5858
# Epoch 10/50, Loss: 0.6895, Val AUC-ROC: 0.6088
# Epoch 11/50, Loss: 0.6883, Val AUC-ROC: 0.6260
# Epoch 12/50, Loss: 0.6869, Val AUC-ROC: 0.6307
# Epoch 13/50, Loss: 0.6850, Val AUC-ROC: 0.6378
# Epoch 14/50, Loss: 0.6825, Val AUC-ROC: 0.6566
# Epoch 41/50, Loss: 0.6682, Val AUC-ROC: 0.6840
# Epoch 42/50, Loss: 0.6677, Val AUC-ROC: 0.6849
# Epoch 43/50, Loss: 0.6671, Val AUC-ROC: 0.6854
# Epoch 44/50, Loss: 0.6666, Val AUC-ROC: 0.6855
# Epoch 45/50, Loss: 0.6660, Val AUC-ROC: 0.6862
# Epoch 46/50, Loss: 0.6655, Val AUC-ROC: 0.6869
# Epoch 47/50, Loss: 0.6649, Val AUC-ROC: 0.6877
# Epoch 48/50, Loss: 0.6643, Val AUC-ROC: 0.6883
# Epoch 49/50, Loss: 0.6637, Val AUC-ROC: 0.6894
# Epoch 50/50, Loss: 0.6632, Val AUC-ROC: 0.6902
# Testing configuration: Hidden Units: 32, Learning Rate: 0.5
# Epoch 1/50, Loss: 0.6923, Val AUC-ROC: 0.5000
# Epoch 2/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 3/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 4/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 5/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 6/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 7/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 8/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 9/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 10/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 11/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 12/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 13/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 14/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 15/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 16/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 17/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 18/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 19/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 20/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 21/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 22/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 23/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 24/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 25/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 26/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 27/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 28/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 29/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 30/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 31/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 32/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 33/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 34/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 35/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 36/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 37/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 38/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 39/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 40/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 41/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 42/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 43/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 44/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 45/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 46/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 47/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 48/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 49/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 50/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Testing configuration: Hidden Units: 32, Learning Rate: 0.1
# Epoch 1/50, Loss: 0.6932, Val AUC-ROC: 0.6712
# Epoch 2/50, Loss: 16.3093, Val AUC-ROC: 0.6678
# Epoch 3/50, Loss: 8.9126, Val AUC-ROC: 0.6716
# Epoch 4/50, Loss: 7.6654, Val AUC-ROC: 0.6771
# Epoch 5/50, Loss: 1.4728, Val AUC-ROC: 0.6930
# Epoch 6/50, Loss: 5.2515, Val AUC-ROC: 0.6877
# Epoch 7/50, Loss: 3.4774, Val AUC-ROC: 0.6804
# Epoch 8/50, Loss: 1.1688, Val AUC-ROC: 0.6824
# Epoch 9/50, Loss: 1.0601, Val AUC-ROC: 0.6881
# Epoch 10/50, Loss: 1.4866, Val AUC-ROC: 0.6916
# Epoch 11/50, Loss: 1.0554, Val AUC-ROC: 0.3717
# Epoch 12/50, Loss: 0.7247, Val AUC-ROC: 0.3168
# Epoch 13/50, Loss: 0.9415, Val AUC-ROC: 0.3134
# Epoch 14/50, Loss: 1.0933, Val AUC-ROC: 0.3101
# Epoch 15/50, Loss: 1.0183, Val AUC-ROC: 0.3092
# Epoch 16/50, Loss: 0.8745, Val AUC-ROC: 0.3147
# Epoch 17/50, Loss: 0.7682, Val AUC-ROC: 0.3366
# Epoch 18/50, Loss: 0.7211, Val AUC-ROC: 0.3700
# Epoch 19/50, Loss: 0.7048, Val AUC-ROC: 0.4057
# Epoch 20/50, Loss: 0.7007, Val AUC-ROC: 0.4290
# Epoch 21/50, Loss: 0.6992, Val AUC-ROC: 0.4527
# Epoch 22/50, Loss: 0.6984, Val AUC-ROC: 0.4687
# Epoch 23/50, Loss: 0.6980, Val AUC-ROC: 0.4824
# Epoch 24/50, Loss: 0.6977, Val AUC-ROC: 0.4908
# Epoch 43/50, Loss: 0.6685, Val AUC-ROC: 0.6964
# Epoch 44/50, Loss: 0.6679, Val AUC-ROC: 0.6969
# Epoch 45/50, Loss: 0.6673, Val AUC-ROC: 0.6977
# Epoch 46/50, Loss: 0.6667, Val AUC-ROC: 0.6978
# Epoch 47/50, Loss: 0.6661, Val AUC-ROC: 0.6981
# Epoch 48/50, Loss: 0.6655, Val AUC-ROC: 0.6984
# Epoch 49/50, Loss: 0.6649, Val AUC-ROC: 0.6985
# Epoch 50/50, Loss: 0.6643, Val AUC-ROC: 0.6986
# Testing configuration: Hidden Units: 64, Learning Rate: 0.5
# Epoch 1/50, Loss: 0.6961, Val AUC-ROC: 0.6465
# Epoch 2/50, Loss: 29.6804, Val AUC-ROC: 0.5000
# Epoch 3/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 4/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 5/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 6/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 7/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 8/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 9/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 10/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 11/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 12/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 13/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 14/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 15/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 16/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 17/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 18/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 19/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 20/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 21/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 22/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 23/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 24/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 25/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 26/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 27/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 28/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 29/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 30/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 31/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 32/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 33/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 34/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 35/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 36/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 37/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 38/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 39/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 40/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 41/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 42/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 43/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 44/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 45/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 46/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 47/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 48/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 49/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 50/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Testing configuration: Hidden Units: 64, Learning Rate: 0.1
# Epoch 1/50, Loss: 0.6955, Val AUC-ROC: 0.6705
# Epoch 2/50, Loss: 7.8375, Val AUC-ROC: 0.5015
# Epoch 3/50, Loss: 49.7233, Val AUC-ROC: 0.5000
# Epoch 4/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 5/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 6/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 7/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 8/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 9/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 10/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 11/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 12/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 13/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 14/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 15/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 16/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 17/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 18/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 19/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 20/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 21/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 22/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 23/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 24/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 25/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 26/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 27/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 28/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 29/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 30/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 31/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 32/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 33/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 34/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 35/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 36/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 37/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 38/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 39/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 40/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 41/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 42/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 43/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 44/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 45/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 46/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 47/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 48/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 49/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 50/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Testing configuration: Hidden Units: 64, Learning Rate: 0.01
# Epoch 1/50, Loss: 0.6985, Val AUC-ROC: 0.6581
# Epoch 2/50, Loss: 1.2628, Val AUC-ROC: 0.6685
# Epoch 3/50, Loss: 0.6713, Val AUC-ROC: 0.5356
# Epoch 4/50, Loss: 0.8688, Val AUC-ROC: 0.5862
# Epoch 5/50, Loss: 0.8457, Val AUC-ROC: 0.6419
# Epoch 6/50, Loss: 0.7806, Val AUC-ROC: 0.6634
# Epoch 7/50, Loss: 0.7250, Val AUC-ROC: 0.6698
# Epoch 8/50, Loss: 0.6925, Val AUC-ROC: 0.6739
# Epoch 9/50, Loss: 0.6787, Val AUC-ROC: 0.6844
# Epoch 10/50, Loss: 0.6790, Val AUC-ROC: 0.6844
# Epoch 11/50, Loss: 0.6775, Val AUC-ROC: 0.6901
# Epoch 12/50, Loss: 0.6756, Val AUC-ROC: 0.6860
# Epoch 13/50, Loss: 0.6741, Val AUC-ROC: 0.6935
# Epoch 14/50, Loss: 0.6707, Val AUC-ROC: 0.6957
# Epoch 15/50, Loss: 0.6686, Val AUC-ROC: 0.7000
# Epoch 16/50, Loss: 0.6655, Val AUC-ROC: 0.7061
# Epoch 17/50, Loss: 0.6624, Val AUC-ROC: 0.7057
# Epoch 18/50, Loss: 0.6597, Val AUC-ROC: 0.7120
# Epoch 19/50, Loss: 0.6563, Val AUC-ROC: 0.7104
# Epoch 20/50, Loss: 0.6538, Val AUC-ROC: 0.7155
# Epoch 21/50, Loss: 0.6498, Val AUC-ROC: 0.7222
# Epoch 22/50, Loss: 0.6470, Val AUC-ROC: 0.7207
# Epoch 23/50, Loss: 0.6429, Val AUC-ROC: 0.7204
# Epoch 24/50, Loss: 0.6406, Val AUC-ROC: 0.7288
# Epoch 25/50, Loss: 0.6363, Val AUC-ROC: 0.7266
# Epoch 26/50, Loss: 0.6336, Val AUC-ROC: 0.7278
# Epoch 27/50, Loss: 0.6296, Val AUC-ROC: 0.7295
# Epoch 28/50, Loss: 0.6272, Val AUC-ROC: 0.7295
# Epoch 29/50, Loss: 0.6231, Val AUC-ROC: 0.7354
# Epoch 30/50, Loss: 0.6205, Val AUC-ROC: 0.7352
# Epoch 31/50, Loss: 0.6168, Val AUC-ROC: 0.7382
# Epoch 32/50, Loss: 0.6143, Val AUC-ROC: 0.7414
# Epoch 33/50, Loss: 0.6107, Val AUC-ROC: 0.7433
# Epoch 34/50, Loss: 0.6077, Val AUC-ROC: 0.7453
# Epoch 35/50, Loss: 0.6050, Val AUC-ROC: 0.7471
# Epoch 36/50, Loss: 0.6014, Val AUC-ROC: 0.7503
# Epoch 37/50, Loss: 0.5988, Val AUC-ROC: 0.7532
# Epoch 38/50, Loss: 0.5955, Val AUC-ROC: 0.7568
# Epoch 39/50, Loss: 0.5929, Val AUC-ROC: 0.7574
# Epoch 40/50, Loss: 0.5895, Val AUC-ROC: 0.7637
# Epoch 41/50, Loss: 0.5869, Val AUC-ROC: 0.7629
# Epoch 42/50, Loss: 0.5831, Val AUC-ROC: 0.7645
# Epoch 43/50, Loss: 0.5796, Val AUC-ROC: 0.7633
# Epoch 44/50, Loss: 0.5756, Val AUC-ROC: 0.7604
# Epoch 45/50, Loss: 0.5711, Val AUC-ROC: 0.7610
# Epoch 46/50, Loss: 0.5663, Val AUC-ROC: 0.7616
# Epoch 47/50, Loss: 0.5601, Val AUC-ROC: 0.7621
# Epoch 48/50, Loss: 0.5538, Val AUC-ROC: 0.7647
# Epoch 49/50, Loss: 0.5465, Val AUC-ROC: 0.7673
# Epoch 50/50, Loss: 0.5390, Val AUC-ROC: 0.7678
# Testing configuration: Hidden Units: 64, Learning Rate: 0.001
# Epoch 1/50, Loss: 0.6934, Val AUC-ROC: 0.6517
# Epoch 2/50, Loss: 0.6851, Val AUC-ROC: 0.6743
# Epoch 3/50, Loss: 0.6782, Val AUC-ROC: 0.6825
# Epoch 4/50, Loss: 0.6719, Val AUC-ROC: 0.6830
# Epoch 5/50, Loss: 0.6658, Val AUC-ROC: 0.6859
# Epoch 6/50, Loss: 0.6601, Val AUC-ROC: 0.6890
# Epoch 7/50, Loss: 0.6549, Val AUC-ROC: 0.6932
# Epoch 8/50, Loss: 0.6500, Val AUC-ROC: 0.6954
# Epoch 9/50, Loss: 0.6453, Val AUC-ROC: 0.6991
# Epoch 10/50, Loss: 0.6408, Val AUC-ROC: 0.7033
# Epoch 11/50, Loss: 0.6362, Val AUC-ROC: 0.7076
# Epoch 12/50, Loss: 0.6316, Val AUC-ROC: 0.7119
# Epoch 13/50, Loss: 0.6269, Val AUC-ROC: 0.7167
# Epoch 14/50, Loss: 0.6222, Val AUC-ROC: 0.7216
# Epoch 15/50, Loss: 0.6174, Val AUC-ROC: 0.7259
# Epoch 16/50, Loss: 0.6125, Val AUC-ROC: 0.7304
# Epoch 17/50, Loss: 0.6077, Val AUC-ROC: 0.7342
# Epoch 18/50, Loss: 0.6029, Val AUC-ROC: 0.7380
# Epoch 19/50, Loss: 0.5982, Val AUC-ROC: 0.7413
# Epoch 20/50, Loss: 0.5937, Val AUC-ROC: 0.7450
# Epoch 21/50, Loss: 0.5892, Val AUC-ROC: 0.7475
# Epoch 22/50, Loss: 0.5849, Val AUC-ROC: 0.7492
# Epoch 23/50, Loss: 0.5808, Val AUC-ROC: 0.7516
# Epoch 24/50, Loss: 0.5767, Val AUC-ROC: 0.7534
# Epoch 25/50, Loss: 0.5727, Val AUC-ROC: 0.7554
# Epoch 26/50, Loss: 0.5688, Val AUC-ROC: 0.7564
# Epoch 27/50, Loss: 0.5649, Val AUC-ROC: 0.7577
# Epoch 28/50, Loss: 0.5612, Val AUC-ROC: 0.7591
# Epoch 29/50, Loss: 0.5574, Val AUC-ROC: 0.7609
# Epoch 30/50, Loss: 0.5538, Val AUC-ROC: 0.7623
# Epoch 31/50, Loss: 0.5503, Val AUC-ROC: 0.7648
# Epoch 32/50, Loss: 0.5468, Val AUC-ROC: 0.7665
# Epoch 33/50, Loss: 0.5435, Val AUC-ROC: 0.7687
# Epoch 34/50, Loss: 0.5402, Val AUC-ROC: 0.7705
# Epoch 35/50, Loss: 0.5369, Val AUC-ROC: 0.7723
# Epoch 36/50, Loss: 0.5337, Val AUC-ROC: 0.7744
# Epoch 37/50, Loss: 0.5306, Val AUC-ROC: 0.7767
# Epoch 38/50, Loss: 0.5275, Val AUC-ROC: 0.7789
# Epoch 39/50, Loss: 0.5244, Val AUC-ROC: 0.7807
# Epoch 40/50, Loss: 0.5214, Val AUC-ROC: 0.7828
# Epoch 41/50, Loss: 0.5184, Val AUC-ROC: 0.7844
# Epoch 42/50, Loss: 0.5155, Val AUC-ROC: 0.7865
# Epoch 43/50, Loss: 0.5126, Val AUC-ROC: 0.7879
# Epoch 44/50, Loss: 0.5097, Val AUC-ROC: 0.7891
# Epoch 45/50, Loss: 0.5069, Val AUC-ROC: 0.7909
# Epoch 46/50, Loss: 0.5041, Val AUC-ROC: 0.7928
# Epoch 47/50, Loss: 0.5013, Val AUC-ROC: 0.7941
# Epoch 48/50, Loss: 0.4986, Val AUC-ROC: 0.7953
# Epoch 49/50, Loss: 0.4959, Val AUC-ROC: 0.7966
# Epoch 50/50, Loss: 0.4933, Val AUC-ROC: 0.7979
# Epoch 43/50, Loss: 0.6577, Val AUC-ROC: 0.6879
# Epoch 44/50, Loss: 0.6569, Val AUC-ROC: 0.6893
# Epoch 45/50, Loss: 0.6561, Val AUC-ROC: 0.6904
# Epoch 46/50, Loss: 0.6553, Val AUC-ROC: 0.6914
# Epoch 47/50, Loss: 0.6546, Val AUC-ROC: 0.6926
# Epoch 48/50, Loss: 0.6538, Val AUC-ROC: 0.6939
# Epoch 49/50, Loss: 0.6530, Val AUC-ROC: 0.6950
# Epoch 50/50, Loss: 0.6523, Val AUC-ROC: 0.6957
# Testing configuration: Hidden Units: 128, Learning Rate: 0.5
# Epoch 1/50, Loss: 0.6946, Val AUC-ROC: 0.5000
# Epoch 2/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 3/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 4/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 5/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 6/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 7/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 8/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 9/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 10/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 11/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 12/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 13/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 14/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 15/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 16/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 17/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 18/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 19/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 20/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 21/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 22/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 23/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 24/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 25/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 26/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 27/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 28/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 29/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 30/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 31/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 32/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 33/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 34/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 35/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 36/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 37/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 38/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 39/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 40/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 41/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 42/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 43/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 44/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 45/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 46/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 47/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 48/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 49/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 50/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Testing configuration: Hidden Units: 128, Learning Rate: 0.1
# Epoch 1/50, Loss: 0.6945, Val AUC-ROC: 0.5905
# Epoch 2/50, Loss: 48.0134, Val AUC-ROC: 0.5000
# Epoch 3/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 4/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 5/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 6/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 7/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 8/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 9/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 10/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 11/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 12/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 13/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 14/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 15/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 16/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 17/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 18/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 19/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 20/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 21/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 22/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 23/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 24/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 25/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 26/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 27/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 28/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 29/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 30/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 31/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 32/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 33/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 34/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 35/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 36/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 37/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 38/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 39/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 40/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 41/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 42/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 43/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 44/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 45/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 46/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 47/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 48/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 49/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Epoch 50/50, Loss: 50.0000, Val AUC-ROC: 0.5000
# Testing configuration: Hidden Units: 128, Learning Rate: 0.01
# Epoch 1/50, Loss: 0.6934, Val AUC-ROC: 0.6733
# Epoch 2/50, Loss: 0.9471, Val AUC-ROC: 0.6710
# Epoch 3/50, Loss: 1.2660, Val AUC-ROC: 0.6722
# Epoch 4/50, Loss: 0.9577, Val AUC-ROC: 0.6821
# Epoch 5/50, Loss: 0.7023, Val AUC-ROC: 0.6935
# Epoch 6/50, Loss: 0.6775, Val AUC-ROC: 0.6935
# Epoch 7/50, Loss: 0.7433, Val AUC-ROC: 0.6914
# Epoch 8/50, Loss: 0.7577, Val AUC-ROC: 0.6983
# Epoch 9/50, Loss: 0.7345, Val AUC-ROC: 0.7027
# Epoch 10/50, Loss: 0.7062, Val AUC-ROC: 0.7007
# Epoch 11/50, Loss: 0.6846, Val AUC-ROC: 0.6975
# Epoch 12/50, Loss: 0.6729, Val AUC-ROC: 0.6947
# Epoch 13/50, Loss: 0.6680, Val AUC-ROC: 0.6938
# Epoch 14/50, Loss: 0.6665, Val AUC-ROC: 0.6933
# Epoch 15/50, Loss: 0.6626, Val AUC-ROC: 0.6845
# Epoch 16/50, Loss: 0.6572, Val AUC-ROC: 0.6862
# Epoch 17/50, Loss: 0.6564, Val AUC-ROC: 0.6868
# Epoch 18/50, Loss: 0.6559, Val AUC-ROC: 0.6880
# Epoch 19/50, Loss: 0.6513, Val AUC-ROC: 0.6897
# Epoch 20/50, Loss: 0.6465, Val AUC-ROC: 0.6923
# Epoch 21/50, Loss: 0.6445, Val AUC-ROC: 0.6939
# Epoch 22/50, Loss: 0.6419, Val AUC-ROC: 0.6973
# Epoch 23/50, Loss: 0.6368, Val AUC-ROC: 0.7000
# Epoch 24/50, Loss: 0.6324, Val AUC-ROC: 0.7038
# Epoch 25/50, Loss: 0.6299, Val AUC-ROC: 0.7081
# Epoch 26/50, Loss: 0.6262, Val AUC-ROC: 0.7122
# Epoch 27/50, Loss: 0.6208, Val AUC-ROC: 0.7156
# Epoch 28/50, Loss: 0.6166, Val AUC-ROC: 0.7198
# Epoch 29/50, Loss: 0.6129, Val AUC-ROC: 0.7252
# Epoch 30/50, Loss: 0.6074, Val AUC-ROC: 0.7295
# Epoch 31/50, Loss: 0.6020, Val AUC-ROC: 0.7343
# Epoch 32/50, Loss: 0.5977, Val AUC-ROC: 0.7389
# Epoch 33/50, Loss: 0.5921, Val AUC-ROC: 0.7425
# Epoch 34/50, Loss: 0.5865, Val AUC-ROC: 0.7451
# Epoch 35/50, Loss: 0.5821, Val AUC-ROC: 0.7480
# Epoch 36/50, Loss: 0.5767, Val AUC-ROC: 0.7508
# Epoch 37/50, Loss: 0.5720, Val AUC-ROC: 0.7524
# Epoch 38/50, Loss: 0.5680, Val AUC-ROC: 0.7533
# Epoch 39/50, Loss: 0.5628, Val AUC-ROC: 0.7549
# Epoch 40/50, Loss: 0.5590, Val AUC-ROC: 0.7554
# Epoch 41/50, Loss: 0.5544, Val AUC-ROC: 0.7568
# Epoch 42/50, Loss: 0.5503, Val AUC-ROC: 0.7593
# Epoch 43/50, Loss: 0.5462, Val AUC-ROC: 0.7623
# Epoch 44/50, Loss: 0.5418, Val AUC-ROC: 0.7645
# Epoch 45/50, Loss: 0.5381, Val AUC-ROC: 0.7671
# Epoch 46/50, Loss: 0.5339, Val AUC-ROC: 0.7695
# Epoch 47/50, Loss: 0.5305, Val AUC-ROC: 0.7727
# Epoch 48/50, Loss: 0.5265, Val AUC-ROC: 0.7748
# Epoch 49/50, Loss: 0.5234, Val AUC-ROC: 0.7775
# Epoch 50/50, Loss: 0.5196, Val AUC-ROC: 0.7798
# Testing configuration: Hidden Units: 128, Learning Rate: 0.001
# Epoch 1/50, Loss: 0.6961, Val AUC-ROC: 0.6466
# Epoch 2/50, Loss: 0.6938, Val AUC-ROC: 0.6569
# Epoch 3/50, Loss: 0.6807, Val AUC-ROC: 0.6672
# Epoch 4/50, Loss: 0.6763, Val AUC-ROC: 0.6769
# Epoch 5/50, Loss: 0.6708, Val AUC-ROC: 0.6839
# Epoch 6/50, Loss: 0.6622, Val AUC-ROC: 0.6857
# Epoch 7/50, Loss: 0.6569, Val AUC-ROC: 0.6864
# Epoch 8/50, Loss: 0.6529, Val AUC-ROC: 0.6907
# Epoch 9/50, Loss: 0.6473, Val AUC-ROC: 0.6944
# Epoch 10/50, Loss: 0.6431, Val AUC-ROC: 0.6978
# Epoch 11/50, Loss: 0.6390, Val AUC-ROC: 0.7020
# Epoch 12/50, Loss: 0.6336, Val AUC-ROC: 0.7063
# Epoch 13/50, Loss: 0.6293, Val AUC-ROC: 0.7128
# Epoch 14/50, Loss: 0.6244, Val AUC-ROC: 0.7181
# Epoch 15/50, Loss: 0.6189, Val AUC-ROC: 0.7235
# Epoch 16/50, Loss: 0.6142, Val AUC-ROC: 0.7281
# Epoch 17/50, Loss: 0.6089, Val AUC-ROC: 0.7328
# Epoch 18/50, Loss: 0.6037, Val AUC-ROC: 0.7367
# Epoch 19/50, Loss: 0.5991, Val AUC-ROC: 0.7405
# Epoch 20/50, Loss: 0.5938, Val AUC-ROC: 0.7450
# Epoch 21/50, Loss: 0.5893, Val AUC-ROC: 0.7476
# Epoch 22/50, Loss: 0.5847, Val AUC-ROC: 0.7490
# Epoch 23/50, Loss: 0.5801, Val AUC-ROC: 0.7508
# Epoch 24/50, Loss: 0.5760, Val AUC-ROC: 0.7526
# Epoch 25/50, Loss: 0.5715, Val AUC-ROC: 0.7543
# Epoch 26/50, Loss: 0.5675, Val AUC-ROC: 0.7559
# Epoch 27/50, Loss: 0.5633, Val AUC-ROC: 0.7582
# Epoch 28/50, Loss: 0.5593, Val AUC-ROC: 0.7608
# Epoch 29/50, Loss: 0.5552, Val AUC-ROC: 0.7631
# Epoch 30/50, Loss: 0.5514, Val AUC-ROC: 0.7650
# Epoch 31/50, Loss: 0.5476, Val AUC-ROC: 0.7667
# Epoch 32/50, Loss: 0.5439, Val AUC-ROC: 0.7690
# Epoch 33/50, Loss: 0.5403, Val AUC-ROC: 0.7708
# Epoch 34/50, Loss: 0.5368, Val AUC-ROC: 0.7731
# Epoch 35/50, Loss: 0.5333, Val AUC-ROC: 0.7749
# Epoch 36/50, Loss: 0.5299, Val AUC-ROC: 0.7765
# Epoch 37/50, Loss: 0.5265, Val AUC-ROC: 0.7787
# Epoch 38/50, Loss: 0.5232, Val AUC-ROC: 0.7806
# Epoch 39/50, Loss: 0.5199, Val AUC-ROC: 0.7827
# Epoch 40/50, Loss: 0.5167, Val AUC-ROC: 0.7843
# Epoch 41/50, Loss: 0.5135, Val AUC-ROC: 0.7864
# Epoch 42/50, Loss: 0.5104, Val AUC-ROC: 0.7887
# Epoch 43/50, Loss: 0.5074, Val AUC-ROC: 0.7906
# Epoch 44/50, Loss: 0.5043, Val AUC-ROC: 0.7929
# Epoch 45/50, Loss: 0.5013, Val AUC-ROC: 0.7946
# Epoch 46/50, Loss: 0.4983, Val AUC-ROC: 0.7959
# Epoch 47/50, Loss: 0.4953, Val AUC-ROC: 0.7971
# Epoch 48/50, Loss: 0.4923, Val AUC-ROC: 0.7986
# Epoch 49/50, Loss: 0.4894, Val AUC-ROC: 0.8008
# Epoch 50/50, Loss: 0.4865, Val AUC-ROC: 0.8023
# Testing configuration: Hidden Units: 128, Learning Rate: 0.0001
# Epoch 1/50, Loss: 0.6970, Val AUC-ROC: 0.5048
# Epoch 2/50, Loss: 0.6947, Val AUC-ROC: 0.5690
# Epoch 3/50, Loss: 0.6928, Val AUC-ROC: 0.6139
# Epoch 4/50, Loss: 0.6912, Val AUC-ROC: 0.6397
# Epoch 5/50, Loss: 0.6900, Val AUC-ROC: 0.6528
# Epoch 6/50, Loss: 0.6888, Val AUC-ROC: 0.6605
# Epoch 7/50, Loss: 0.6877, Val AUC-ROC: 0.6677
# Epoch 8/50, Loss: 0.6865, Val AUC-ROC: 0.6698
# Epoch 9/50, Loss: 0.6853, Val AUC-ROC: 0.6708
# Epoch 10/50, Loss: 0.6841, Val AUC-ROC: 0.6720
# Epoch 11/50, Loss: 0.6829, Val AUC-ROC: 0.6724
# Epoch 12/50, Loss: 0.6816, Val AUC-ROC: 0.6725
# Epoch 13/50, Loss: 0.6803, Val AUC-ROC: 0.6730
# Epoch 14/50, Loss: 0.6791, Val AUC-ROC: 0.6740
# Epoch 15/50, Loss: 0.6780, Val AUC-ROC: 0.6736
# Epoch 16/50, Loss: 0.6769, Val AUC-ROC: 0.6744
# Epoch 17/50, Loss: 0.6759, Val AUC-ROC: 0.6748
# Epoch 18/50, Loss: 0.6748, Val AUC-ROC: 0.6754
# Epoch 19/50, Loss: 0.6738, Val AUC-ROC: 0.6757
# Epoch 20/50, Loss: 0.6728, Val AUC-ROC: 0.6768
# Epoch 21/50, Loss: 0.6718, Val AUC-ROC: 0.6770
# Epoch 22/50, Loss: 0.6708, Val AUC-ROC: 0.6768
# Epoch 23/50, Loss: 0.6698, Val AUC-ROC: 0.6771
# Epoch 24/50, Loss: 0.6688, Val AUC-ROC: 0.6777
# Epoch 25/50, Loss: 0.6678, Val AUC-ROC: 0.6781
# Epoch 26/50, Loss: 0.6668, Val AUC-ROC: 0.6793
# Epoch 27/50, Loss: 0.6659, Val AUC-ROC: 0.6801
# Epoch 28/50, Loss: 0.6650, Val AUC-ROC: 0.6810
# Epoch 29/50, Loss: 0.6641, Val AUC-ROC: 0.6820
# Epoch 30/50, Loss: 0.6631, Val AUC-ROC: 0.6829
# Epoch 31/50, Loss: 0.6622, Val AUC-ROC: 0.6839
# Epoch 32/50, Loss: 0.6612, Val AUC-ROC: 0.6847
# Epoch 33/50, Loss: 0.6603, Val AUC-ROC: 0.6850
# Epoch 34/50, Loss: 0.6594, Val AUC-ROC: 0.6862
# Epoch 35/50, Loss: 0.6584, Val AUC-ROC: 0.6871
# Epoch 36/50, Loss: 0.6575, Val AUC-ROC: 0.6877
# Epoch 37/50, Loss: 0.6566, Val AUC-ROC: 0.6888
# Epoch 38/50, Loss: 0.6557, Val AUC-ROC: 0.6897
# Epoch 39/50, Loss: 0.6548, Val AUC-ROC: 0.6908
# Epoch 40/50, Loss: 0.6538, Val AUC-ROC: 0.6915
# Epoch 41/50, Loss: 0.6529, Val AUC-ROC: 0.6922
# Epoch 42/50, Loss: 0.6520, Val AUC-ROC: 0.6929
# Epoch 43/50, Loss: 0.6511, Val AUC-ROC: 0.6940
# Epoch 44/50, Loss: 0.6502, Val AUC-ROC: 0.6949
# Epoch 45/50, Loss: 0.6493, Val AUC-ROC: 0.6961
# Epoch 46/50, Loss: 0.6484, Val AUC-ROC: 0.6972
# Epoch 47/50, Loss: 0.6475, Val AUC-ROC: 0.6985
# Epoch 48/50, Loss: 0.6466, Val AUC-ROC: 0.7002
# Epoch 49/50, Loss: 0.6457, Val AUC-ROC: 0.7010
# Epoch 50/50, Loss: 0.6448, Val AUC-ROC: 0.7021
# Best Model Parameters: {'hidden_units': 8, 'learning_rate': 0.01}
# Best Model AUC-ROC: 0.8110751714322681

# %%
def save_parameters(params, directory, filename="best_model_params.txt"):
    file_path = os.path.join(directory, filename)
    with open(file_path, 'w') as file:
        for key, value in params.items():
            file.write(f"{key}: {value}\n")


save_parameters(best_params, output_directory)

# %%
# Directory where you want to save outputs
tuned_output_directory = f'./saved_models/MED-BERT/trained_on_{percentage}/tuned/'
os.makedirs(tuned_output_directory)
model_name = 'tuned-Med-BERT'  # Name of the model, used for saving outputs

# Call the evaluate function
evaluate_model(best_model, test_embeddings, label_tensor_test, output_directory, model_name, beta=2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Directory where you want to save outputs
# ----> 2 tuned_output_directory = f'./saved_models/MED-BERT/trained_on_{percentage}/tuned/'
#       3 model_name = 'tuned-Med-BERT'  # Name of the model, used for saving outputs
#       5 # Call the evaluate function
#
# NameError: name 'percentage' is not defined

# %%
best_params
# Out:
# {'hidden_units': 8, 'learning_rate': 0.01}

# %%
# Save model and optimizer state
torch.save({
    'model_state_dict': model.state_dict(),
    'optimizer_state_dict': optimizer.state_dict(),
}, f'./saved_models/Med-BERT/trained_on_{percentage}/best-tuned-Med-BERT-model.pth')

# %% [markdown]
# # Attribution Analysis

# %%
def attribute_to_input(model, input_tensor):
    # Create an instance of IntegratedGradients using the model
    integrated_gradients = IntegratedGradients(model)
    
    # Create a tensor of zeros with the same batch size as input_tensor
    target = torch.zeros(input_tensor.shape[0], dtype=torch.int64)
    
    # Calculate the attributions
    attributions = integrated_gradients.attribute(input_tensor, target=target)
    
    # Return the mean of the attributions across all examples
    return attributions.mean(dim=0)  # Averaging attributions over the batch if necessary

# Compute attributions with custom function
attributions = attribute_to_input(model, train_embeddings)

# %%
# Convert the attributions to a numpy array and take the absolute to consider overall impact
attributions_array = attributions.detach().numpy()  # assuming the data is on CPU

# Generate a bar chart
feature_names = [f"Feature {i}" for i in range(len(attributions_array))]  # Replace with real feature names if available
importance_scores = np.abs(attributions_array)

# Sort features by importance
sorted_indices = np.argsort(importance_scores)[::-1]
sorted_features = [feature_names[idx] for idx in sorted_indices]
sorted_importance = importance_scores[sorted_indices]

plt.figure(figsize=(10, 8))
plt.bar(sorted_features[:20], sorted_importance[:20], color='b')  # Adjust the slice for more or fewer features
plt.xticks(rotation=90)
plt.title('Top 20 Important Features')
plt.xlabel('Features')
plt.ylabel('Importance (Absolute Attribution)')
plt.show()

# %%
# Map each sequence of tokens back to their corresponding ICD codes; extract token to ICD code mapping from the tokenized sequences
icd_code_to_tokens = {}
for index, row in train_icd_sequences.iterrows():
    # tokenize the icd_sequence to get token ids
    tokens = tokenizer.encode(row['icd_sequence'], add_special_tokens=False)
    icd_codes = row['icd_sequence'].split()
    for code, token in zip(icd_codes, tokens):
        if code not in icd_code_to_tokens:
            icd_code_to_tokens[code] = []
        icd_code_to_tokens[code].append(token)

# %%
def compute_attributions(model, embeddings):
    # Ensure `embeddings` is on the same device as the model's parameters.
    embeddings = embeddings.to(model.fc1.weight.device)
    integrated_gradients = IntegratedGradients(model)
    
    # Create a baseline which is a tensor of zeros with the same shape as the embeddings
    baselines = torch.zeros_like(embeddings)

    # Compute attributions using Integrated Gradients
    attributions = integrated_gradients.attribute(inputs=embeddings,
                                                  baselines=baselines,
                                                  target=0)
    return attributions.sum(dim=-1)

# %%
# Compute attributions using the embeddings
attributions = compute_attributions(model, train_embeddings)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[39], line 2
#       1 # Compute attributions using the embeddings
# ----> 2 attributions = compute_attributions(model, train_embeddings)
#
# Cell In[38], line 12, in compute_attributions(model, embeddings)
#       8 baselines = torch.zeros_like(embeddings)
#      10 # Compute attributions using Integrated Gradients
#      11 # `target=0` is appropriate here assuming you're interested in the output of the sigmoid for class '1'
# ---> 12 attributions = integrated_gradients.attribute(inputs=embeddings,
#      13                                               baselines=baselines,
#      14                                               target=0)
#      16 # Since there's no sequence dimension, the sum across feature dimension directly aggregates per-input attributions
#      17 return attributions.sum(dim=-1)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\captum\log\__init__.py:42, in log_usage.<locals>._log_usage.<locals>.wrapper(*args, **kwargs)
#      40 @wraps(func)
#      41 def wrapper(*args, **kwargs):
# ---> 42     return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\captum\attr\_core\integrated_gradients.py:286, in IntegratedGradients.attribute(self, inputs, baselines, target, additional_forward_args, n_steps, method, internal_batch_size, return_convergence_delta)
#     274     attributions = _batch_attribution(
#     275         self,
#     276         num_examples,
#    (...)
#     283         method=method,
#     284     )
#     285 else:
# --> 286     attributions = self._attribute(
#     287         inputs=inputs,
#     288         baselines=baselines,
#     289         target=target,
#     290         additional_forward_args=additional_forward_args,
#     291         n_steps=n_steps,
#     292         method=method,
#     293     )
#     295 if return_convergence_delta:
#     296     start_point, end_point = baselines, inputs
#
# File ~\AppData\Roaming\Python\Python311\site-packages\captum\attr\_core\integrated_gradients.py:351, in IntegratedGradients._attribute(self, inputs, baselines, target, additional_forward_args, n_steps, method, step_sizes_and_alphas)
#     348 expanded_target = _expand_target(target, n_steps)
#     350 # grads: dim -> (bsz * #steps x inputs[0].shape[1:], ...)
# --> 351 grads = self.gradient_func(
#     352     forward_fn=self.forward_func,
#     353     inputs=scaled_features_tpl,
#     354     target_ind=expanded_target,
#     355     additional_forward_args=input_additional_args,
#     356 )
#     358 # flattening grads so that we can multilpy it with step-size
#     359 # calling contiguous to avoid `memory whole` problems
#     360 scaled_grads = [
#     361     grad.contiguous().view(n_steps, -1)
#     362     * torch.tensor(step_sizes).view(n_steps, 1).to(grad.device)
#     363     for grad in grads
#     364 ]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\captum\_utils\gradient.py:119, in compute_gradients(forward_fn, inputs, target_ind, additional_forward_args)
#     113     assert outputs[0].numel() == 1, (
#     114         "Target not provided when necessary, cannot"
#     115         " take gradient with respect to multiple outputs."
#     116     )
#     117     # torch.unbind(forward_out) is a list of scalar tensor tuples and
#     118     # contains batch_size * #steps elements
# --> 119     grads = torch.autograd.grad(torch.unbind(outputs), inputs)
#     120 return grads
#
# File ~\AppData\Roaming\Python\Python311\site-packages\torch\autograd\__init__.py:394, in grad(outputs, inputs, grad_outputs, retain_graph, create_graph, only_inputs, allow_unused, is_grads_batched, materialize_grads)
#     390     result = _vmap_internals._vmap(vjp, 0, 0, allow_none_pass_through=True)(
#     391         grad_outputs_
#     392     )
#     393 else:
# --> 394     result = Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     395         t_outputs,
#     396         grad_outputs_,
#     397         retain_graph,
#     398         create_graph,
#     399         t_inputs,
#     400         allow_unused,
#     401         accumulate_grad=False,
#     402     )  # Calls into the C++ engine to run the backward pass
#     403 if materialize_grads:
#     404     result = tuple(
#     405         output
#     406         if output is not None
#     407         else torch.zeros_like(input, requires_grad=True)
#     408         for (output, input) in zip(result, t_inputs)
#     409     )
#
# KeyboardInterrupt:

# %%
plt.figure(figsize=(10, 5))
plt.hist(attributions.numpy(), bins=50, color='skyblue')
plt.title('Distribution of Attribution Values')
plt.xlabel('Attribution')
plt.ylabel('Frequency')
plt.show()

# %%
# Convert attributions to a numpy array for easier handling
attributions_np = attributions.numpy()

# Get indices of the top positive and negative attributions
top_positive_indices = attributions_np.argsort()[-10:][::-1]  # Top 10 positive
top_negative_indices = attributions_np.argsort()[:10]          # Top 10 negative

print("Top Positive Attribution Indices and Values:")
for idx in top_positive_indices:
    print(f"Index: {idx}, Attribution: {attributions_np[idx]}")

print("\nTop Negative Attribution Indices and Values:")
for idx in top_negative_indices:
    print(f"Index: {idx}, Attribution: {attributions_np[idx]}")
# Out:
# Top Positive Attribution Indices and Values:
# Index: 2012, Attribution: 0.5040831620623162
# Index: 2659, Attribution: 0.5040831620623162
# Index: 2963, Attribution: 0.5040831620623162
# Index: 324, Attribution: 0.5040831620623162
# Index: 2284, Attribution: 0.5040831620623162
# Index: 2930, Attribution: 0.5040831620623162
# Index: 1686, Attribution: 0.5040831620623162
# Index: 2937, Attribution: 0.5040831620623162
# Index: 1892, Attribution: 0.5040831620623162
# Index: 2453, Attribution: 0.504026791989485
#
# Top Negative Attribution Indices and Values:
# Index: 6, Attribution: -0.49077006525108857
# Index: 167, Attribution: -0.4905147472369016
# Index: 1215, Attribution: -0.49044225596177343
# Index: 1112, Attribution: -0.49029830430784455
# Index: 479, Attribution: -0.4902456565725166
# Index: 1244, Attribution: -0.49024082995420537
# Index: 477, Attribution: -0.49013884460289936
# Index: 998, Attribution: -0.4901335176007504
# Index: 624, Attribution: -0.48999761289108235
# Index: 1285, Attribution: -0.48996596554099997

# %%
# Prepare a dictionary to hold the aggregated attributions for each ICD code
icd_code_attributions = {}

# Iterate over each ICD code and its list of tokens
for icd_code, tokens in icd_code_to_tokens.items():
    # Filter out the attributions for tokens associated with the current ICD code
    token_attributions = [attributions[token_id] for token_id in set(tokens) if token_id < len(attributions)]
    if token_attributions:
        # Calculate the mean attribution for the current ICD code
        icd_code_attributions[icd_code] = np.mean(token_attributions)

# Sort the ICD codes by their average attributions
sorted_icd_code_attributions = sorted(icd_code_attributions.items(), key=lambda x: x[1], reverse=True)

# Save the attributions to a csv file
sorted_icd_code_attributions_df = pd.DataFrame(sorted_icd_code_attributions, columns=["ICD-Code", "Attribution"])
sorted_icd_code_attributions_df.to_csv(f"./saved_models/Med-BERT/trained_on_{percentage}/icd_code_attributions.csv")

# %%
# Prepare the data for plotting
icd_codes, attributions = zip(*sorted_icd_code_attributions)  # Unzip the list of tuples into two tuples

# Let's plot the top 20 ICD codes for clarity
top_n = 20
icd_codes_top = icd_codes[:top_n]
attributions_top = attributions[:top_n]

# Creating the bar plot
plt.figure(figsize=(12, 8))
plt.barh(icd_codes_top, attributions_top, color='skyblue')
plt.xlabel('Attribution Score')
plt.ylabel('ICD Code')
plt.title(f'Top ICD Codes by Attribution Score (trained on {percentage})')
plt.gca().invert_yaxis()  # Invert the y-axis to have the highest values on top
plt.savefig(f"./saved_models/Med-BERT/trained_on_{percentage}/top_icd_attributions", bbox_inches='tight')
plt.show()

# %%
def icd_to_category(icd_code):
    if icd_code.startswith('A') or icd_code.startswith('B'):
        return 'Infectious and Parasitic Diseases'
    elif icd_code.startswith('C') or (icd_code.startswith('D') and int(icd_code[1:]) < 50):
        return 'Neoplasms'
    elif (icd_code.startswith('D') and int(icd_code[1:]) >= 50):
        return 'Diseases of the Blood and Blood-Forming Organs and Certain Disorders Involving the Immune Mechanism'
    elif icd_code.startswith('E'):
        return 'Endocrine, Nutritional and Metabolic Diseases'
    elif icd_code.startswith('F'):
        return 'Mental and Behavioral Disorders'
    elif icd_code.startswith('G'):
        return 'Diseases of the Nervous System'
    elif icd_code.startswith('H') and int(icd_code[1:]) < 60:
        return 'Diseases of the Eye and Adnexa'
    elif icd_code.startswith('H') and int(icd_code[1:]) >= 60:
        return 'Diseases of the Ear and Mastoid Process'
    elif icd_code.startswith('I'):
        return 'Circulatory System Diseases'
    elif icd_code.startswith('J'):
        return 'Diseases of the Respiratory System'
    elif icd_code.startswith('K'):
        return 'Diseases of the Digestive System'
    elif icd_code.startswith('L'):
        return 'Diseases of the Skin and Subcutaneous Tissue'
    elif icd_code.startswith('M'):
        return 'Diseases of the Musculoskeletal System and Connective Tissue'
    elif icd_code.startswith('N'):
        return 'Diseases of the Genitourinary System'
    elif icd_code.startswith('O'):
        return 'Pregnancy, Childbirth and the Puerperium'
    elif icd_code.startswith('P'):
        return 'Certain Conditions Originating in the Perinatal Period'
    elif icd_code.startswith('Q'):
        return 'Congenital Malformations, Deformations and Chromosomal Abnormalities'
    elif icd_code.startswith('R'):
        return 'Symptoms, Signs and Abnormal Clinical and Laboratory Findings, Not Elsewhere Classified'
    elif icd_code.startswith('S') or icd_code.startswith('T'):
        return 'Injury, Poisoning and Certain Other Consequences of External Causes'
    elif icd_code.startswith('V') or icd_code.startswith('W') or icd_code.startswith('X') or icd_code.startswith('Y'):
        return 'External Causes of Morbidity'
    elif icd_code.startswith('Z'):
        return 'Factors Influencing Health Status and Contact with Health Services'
    else:
        return 'Other'


# Apply the Mapping
icd_categories = {code: icd_to_category(code) for code in icd_code_to_tokens.keys()}

# %%
# Initialize a dictionary to hold summed attributions by category
category_attributions = defaultdict(float)
category_counts = defaultdict(int)

for icd_code, attribution in icd_code_attributions.items():
    category = icd_to_category(icd_code)
    category_attributions[category] += attribution
    category_counts[category] += 1

# Calculate the average attribution per category
category_average_attributions = {cat: category_attributions[cat] / category_counts[cat] for cat in category_attributions}

# %%
categories, avg_attributions = zip(*sorted(category_average_attributions.items(), key=lambda x: x[1], reverse=True))

plt.figure(figsize=(12, 8))
plt.barh(categories, avg_attributions, color='lightgreen')
plt.xlabel('Average Attribution Score')
plt.ylabel('Diagnosis Category')
plt.title(f'Average Attribution by Diagnosis Category (trained on {percentage})')
plt.gca().invert_yaxis()
plt.savefig(f"./saved_models/Med-BERT/trained_on_{percentage}/top_category_attributions", bbox_inches='tight')
plt.show()
